# %% [markdown]
# # Topic Modelling for a Single Product

# %%
import pandas as pd
import pickle
import numpy as np

# %%
# Read the preprocessed data file
df_huge = pd.read_pickle('../Clean_data')
df_huge.head()
df_huge.shape
# Out:
# (19525627, 5)

# %%
# Selection of product- product with maximum review data
df_grouped = df_huge.groupby(['asin']).agg({'reviewText': ' ** '.join,'asin':'size'}).rename(columns={'asin':'count'}).reset_index()
df_grouped.sort_values(by = 'count',ascending=False,inplace=True)
df_grouped.head(30)
# Out:
#                asin                                         reviewText  count
# 580956   B00FLYWNYQ  This is my first pressure cooker so I wasn't r...  22704
# 836347   B00Q7EV29G  This mattress shipped free via 2 day Prime Shi...  15201
# 551006   B00EINBSJ2  I received my pillow on time as stated on Frid...  14856
# 409335   B009HVH4XO  i have 4 of these and i didn't think they coul...  14649
# 742237   B00LV4W8BI  The sheets are very soft and comfortable right...  13507
# 790907   B00NX47YP4  I love this little scale. It's simple, easy to...  12971
# 1102682  B019D9HESO  LOVE this cup! Keeps my drink from getting wat...  11770
# 420105   B009ZJ2M7G  My unreliable Bissell 2x scrubber recently bro...  10518
# 391650   B00902X68W  The sheets are some of the softest and  most c...  10026
# 503326   B00COK3FD8  The tupperware was exactly as described. I lov...   9171
# 393824   B0091YYUAM  Mopping is one of those things I really dislik...   8896
# 366193   B007WQ9YNE  I used to think that a rice cooker was a pot o...   8872
# 908309   B00VANO9OE  These are the softest sheets that I've ever fe...   8297
# 86088    B001892AX2  Mine arrived yesterday; timely, in good shape,...   8154
# 662479   B00IR77HOK  I got a 16 oz one. The lid is very well design...   7987
# 934554   B00X8KSKF6  I love these bags, I was given the opportunity...   7945
# 532317   B00DU1R19E  The quality is good for the low price. It seem...   7837
# 782825   B00NLLUNSE  These sheets came on time, quality is superb, ...   7690
# 122028   B001PB8EJ2  Quick and good.  This is my second one.  The b...   7543
# 754899   B00MG2OOHK  Easy to use, fast results, very good price. I ...   7311
# 1018251  B014P3B7TU  I just received this vacuum today. My stairs h...   7306
# 692139   B00JVLG2KG  This thermos is the BEST!  I have opened it an...   7227
# 5393     B00009R66F  Purchased this product after looking around an...   7198
# 55148    B000RL1WNQ  It is definitely tough shopping by looking onl...   7186
# 1095104  B018UQ5AMS  It's awesome nice hot cup every time //Outstan...   7183
# 61595    B000VENLF6  Very happy with the Pike Street overfilled ult...   7175
# 67600    B000YGEVMI  My 3 year old son had this thermos and loved i...   7149
# 978800   B0118DYK3K  Awesome product. My husband and I bought 2 of ...   7036
# 3173     B00005UP2N  We've had our Kitchenaid for about 15 years no...   6867
# 558510   B00ETP7D3E  This was completely worth the money!  Keeps co...   6813

# %%
df_B00FLYWNYQ = df_huge.loc[df_huge['asin'] == "B00FLYWNYQ"]

# %%
df_B00FLYWNYQ
# Out:
#           overall      reviewerID        asin  \
# 2290534       5.0  A38QLFND44V8QG  B00FLYWNYQ
# 2321609       5.0  A33BHZZ03JPSQ2  B00FLYWNYQ
# 2331312       5.0   AN5GO0DDAQNSW  B00FLYWNYQ
# 2349417       5.0   A7JD2EUAVIPYD  B00FLYWNYQ
# 2375015       5.0  A1U8VI6I2MFEU8  B00FLYWNYQ
# ...           ...             ...         ...
# 19286662      5.0  A2UYXOX0E4RCUU  B00FLYWNYQ
# 19286668      5.0  A15FO6FUAIWX4M  B00FLYWNYQ
# 19286678      1.0   AJHC8VUSCAFLI  B00FLYWNYQ
# 19286681      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 19286682      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
#
#                                                  reviewText   rev_date
# 2290534   This is my first pressure cooker so I wasn't r... 2014-01-04
# 2321609   I was excited to try this so as soon as I got ... 2014-01-08
# 2331312   Got it yesterday and it seems to be defective.... 2014-01-09
# 2349417   8/22/15 ** UPDATE **\n\nSTILL LOVING THIS BABY... 2014-01-12
# 2375015   Some of the positive reviews here have express... 2014-01-15
# ...                                                     ...        ...
# 19286662  I understand why there is a craze for this pro... 2018-07-21
# 19286668                            Love this! //Five Stars 2018-07-21
# 19286678  This is the second Instant Pot Mini I purchase... 2018-07-21
# 19286681  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 19286682  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
#
# [22704 rows x 5 columns]

# %%
df_B00FLYWNYQ['overall'].describe()
# Out:
# count    22704.000000
# mean         4.599850
# std          1.015574
# min          1.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: overall, dtype: float64

# %% [markdown]
# ## Preparing the dataframe with review sentences

# %%
# Preapre a data frame by spliiting reviews into sentences
df_sentences = pd.DataFrame(df_B00FLYWNYQ.reviewText.str.split('.').tolist(), index=df_B00FLYWNYQ.reviewerID).stack()
df_sentences = df_sentences.reset_index([0, 'reviewerID'])
df_sentences.columns = ['reviewerID', 'sentences']

df_sentences
# Out:
#             reviewerID                                          sentences
# 0       A38QLFND44V8QG  This is my first pressure cooker so I wasn't r...
# 1       A38QLFND44V8QG    That being said, I found it very intuitive a...
# 2       A38QLFND44V8QG    To try it out I decided to start with someth...
# 3       A38QLFND44V8QG    This product comes with recommended cooking ...
# 4       A38QLFND44V8QG                  I would have been lost without it
# ...                ...                                                ...
# 116451  A27HMTTTL9X72A    I bought the smaller one for everyday since ...
# 116452  A27HMTTTL9X72A    It's just as wonderful as the bigger one, bu...
# 116453  A27HMTTTL9X72A                                      //Great for 2
# 116454  A2KXZ2A335QDI8  I love my Due Mini!  It is fun to use--and it ...
# 116455  A2KXZ2A335QDI8                                //Great Applicance!
#
# [116456 rows x 2 columns]

# %%
# Merging the 50 reviews dataframe having all columns with new sentences dataframe
df_full = df_B00FLYWNYQ.merge(df_sentences, how='inner', left_on='reviewerID', right_on='reviewerID')
df_full_copy = df_B00FLYWNYQ.merge(df_sentences, how='inner', left_on='reviewerID', right_on='reviewerID')
df_full_copy

# #  Removed unneccesary columns 
# df_50p_5800r = df_50p_5800r.drop(["reviewText", "rev_date", "product_ID"], axis=1)
# df_50p_5800r = df_50p_5800r

# df_B00ETP7D3E_full.head()
# Out:
#         overall      reviewerID        asin  \
# 0           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 1           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 2           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 3           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 4           5.0  A38QLFND44V8QG  B00FLYWNYQ
# ...         ...             ...         ...
# 116451      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116452      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116453      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116454      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
# 116455      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
#
#                                                reviewText   rev_date  \
# 0       This is my first pressure cooker so I wasn't r... 2014-01-04
# 1       This is my first pressure cooker so I wasn't r... 2014-01-04
# 2       This is my first pressure cooker so I wasn't r... 2014-01-04
# 3       This is my first pressure cooker so I wasn't r... 2014-01-04
# 4       This is my first pressure cooker so I wasn't r... 2014-01-04
# ...                                                   ...        ...
# 116451  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116452  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116453  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116454  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
# 116455  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
#
#                                                 sentences
# 0       This is my first pressure cooker so I wasn't r...
# 1         That being said, I found it very intuitive a...
# 2         To try it out I decided to start with someth...
# 3         This product comes with recommended cooking ...
# 4                       I would have been lost without it
# ...                                                   ...
# 116451    I bought the smaller one for everyday since ...
# 116452    It's just as wonderful as the bigger one, bu...
# 116453                                      //Great for 2
# 116454  I love my Due Mini!  It is fun to use--and it ...
# 116455                                //Great Applicance!
#
# [116456 rows x 6 columns]

# %% [markdown]
# ## LDA Modeling

# %%
import time

import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
# Get sentences from the data frame
list_sentences = df_sentences.sentences.values.tolist()
print(list_sentences[:1], len(list_sentences))
# Out:
# ["This is my first pressure cooker so I wasn't really sure what to expect"] 116456

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

list_sentences_tokenized = list(sent_to_words(list_sentences))
list_sentences_tokenized_copy = list(sent_to_words(list_sentences))
print(list_sentences_tokenized_copy[:1])
# Out:
# [['this', 'is', 'my', 'first', 'pressure', 'cooker', 'so', 'wasn', 'really', 'sure', 'what', 'to', 'expect']]

# %%
# Build the bigram and trigram models

start_time = time.time()

bigram = gensim.models.Phrases(list_sentences_tokenized, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[list_sentences_tokenized], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[list_sentences_tokenized[0]]])

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ['this', 'is', 'my', 'first', 'pressure', 'cooker', 'so', 'wasn', 'really', 'sure', 'what', 'to', 'expect']
# --- 13.008661985397339 seconds ---

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(list_sentences_tokenized)
data_words_nostops[:1]
# Out:
# [['first', 'pressure', 'cooker', 'really', 'sure', 'expect']]

# %%
# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)
data_words_bigrams[:1]
# Out:
# [['first', 'pressure', 'cooker', 'really', 'sure', 'expect']]

# %%
start_time = time.time()
# # Remove Stop Words 
# data_words_nostops = remove_stopwords(list_sentences_tokenized)

# # Form Bigrams
# data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# # Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [['first', 'pressure', 'cooker', 'really', 'sure', 'expect']]

# %%
#  For Text Blob
from nltk.tokenize.treebank import TreebankWordDetokenizer
list_sentences_lemetised = []
for i in range(len(data_lemmatized)):
    lem_sen = TreebankWordDetokenizer().detokenize(data_lemmatized[i])
    list_sentences_lemetised.append(lem_sen)

# %%
list_sentences_lemetised
# Out:
# ['first pressure cooker really sure expect',
#  'say find intuitive easy make sure read instruction though',
#  'try decide start simple bake chicken',
#  'product come recommend cooking time various food come handy',
#  'would lose',
#  'follow instruction chicken come perfect lot less time use',
#  'also take much time',
#  'build quality also top notch',
#  'wait try new recipe',
#  'love',
#  'excited try soon get follow manual set brown rice recipe include cookbook instead use rice program button',
#  'end good texture ever brown jasmine rice',
#  'aroma stay pot rice really fragrant read manual figure rice program see work super simple set manually',
#  'pressure cooker ever see own separate one combine cooker',
#  'quiet musical beep opening closing lid tiny whisper steam whole cooking time',
#  'tell display front metal part lid hot touch side',
#  'could tell cooking time end chime pressure cycle end',
#  'automatic warm hold nice timer continue know long food holding',
#  'back need',
#  'stay pot',
#  'people post inner pot come clean brand new show grain mark',
#  'care feel clean expect show',
#  'thought report different experience',
#  'rate feature program try yet pleased purchase base past experience rice cooker pressure cooker combination cooker',
#  'use immediately good brown jasmine rice ever',
#  'get yesterday seem defective',
#  'build pressure give code',
#  'finish cooking roast slow cooker mode seem work fine',
#  'instant pot say send new',
#  'also inner pot hold maximum',
#  'quart fill capacity',
#  'never suppose fill full',
#  'really quart capacity',
#  'also marking inside pot indicate hold cup maximum marking apparently wrong',
#  'wish get model maker',
#  'see new long take ship',
#  'adjust rating afterwards',
#  'initially give star',
#  'update receive replacement base work well',
#  'try cook thing great',
#  'company even ask return defective base acknowledge marking pot measuring cup wrong explain',
#  'seem good product far',
#  'change rating star',
#  'initially defective company replace quickly',
#  '',
#  'update still love baby thankful experienced single problem malfunction unit regularly',
#  'discover simple recipe ip even',
#  'good quality juicer basic great start healther cooking style',
#  'purchase stainless_steel inner pot many wonderful option mode',
#  'aware flaking aluminum cookware related disease health concern',
#  'especially ip lid feature entire lid away unit rest fin slot side',
#  'handy feature southpaw',
#  'also love small footprint unit compare hulk elite pc use pot mode make onion chicken green bean malfunction scorch feature work well cook pot',
#  'make hard_boiled egg use pressure shell peel easily egg purchase day fridge come perfect smell previously cook food constant problem elite easy clean stick simple fix fizz right multiple attempt elite qt pc',
#  'shame duo pancake use slow cooker function make vegetarian find user_friendly',
#  'unit whisper',
#  'notice steam hiss quick press lid render silent',
#  'use elite pc heavily never like tricky lid',
#  'use use ip duo go back',
#  'also bottom elite pc hard clean food stick burn',
#  'put elite',
#  'digital pressure cooker storage donate church give need',
#  'regret family huge yogurt use function curious see homemade yogurt taste store buy variety',
#  'especially video youtube help start include recipe book helpful guideline steam fresh veggie',
#  'go try fish curry recipe later week',
#  'also attempt make clot cream make clot slow cooker use warm feature slowly scald fresh experiment ip clot',
#  'come duo purchase immediately reviewer suggest purchase extra inner pot correspond glass_lid slow cooker mode',
#  'thank instant pot make love love love regret',
#  'express many wonderful aspect instant pot feel need repeat',
#  'agree top pressure cooker person year really knowledgable electric pressure cooker',
#  'lately search online pressure cooker recipe start notice many people love electric pressure cooker',
#  'draw convenience set forget well many function electric pressure cooker offer',
#  'address illustrate advice pressure cooker spite say electric pressure cooker electric pot perform several function quite place category stove top pressure cooker',
#  'opinion test together designate electric pressure cooker feature',
#  'almost try compare apple orange speak',
#  'illustrate learn cook',
#  '',
#  '',
#  'instant pot long tell useful time save addition kitchen right side regular pressure cooker',
#  'stove top pressure cooker try cook different thing time find cumbersome attention draining',
#  'problem instant pot easy fire simutaneously instant pot take require little monitoring',
#  'love green plop instant pot go',
#  'perfect talk fast dinner easy cleanup',
#  'note cooking retain nutritional value food stove top method',
#  '',
#  '',
#  'easy cleanup',
#  'include wipe top range',
#  'choose instant pot research brand appear cooker least complaint fact come stainless_steel bowl',
#  'healthy peel ready order last year model see new model release also make huge wait',
#  'really impressed quality cooker feel look thought construct',
#  'thorough cover detail instantpot include instruction usage well troubleshoot care',
#  'receive watch video youtube carefully go go trial run suggest try first',
#  'smooth sail easy figure',
#  'dish test brown ossobuco turn delicious',
#  'make change ossobuco next time',
#  'use stew normal next time go stew less meat bit overcook like',
#  'flavor awesome cooked meat tad long release much flavor broth',
#  'brown rice perfect',
#  'say impress quickly pot come pressure especially hot liquid',
#  'heat liquid rice braise liquid let heat saute high add put lid',
#  'come pressure quickly',
#  'note pre heated braise liquid mix simmer diced tomato braising liquid want give quick stir placing lid sit place long super heated bottom possibly burn come pressure',
#  'good trick question mix tomato_sauce sweet item pot',
#  'first right put lid bring pressure',
#  'far love instantpot',
#  'extremely user_friendly appear good quality',
#  'describe',
#  'try new recipe use side stove top cooker',
#  'find come pressure cooker simply taste better even simple potato carrot learn curb timing get think would agree food taste better cooked pressure cooker',
#  'time see well instant pot hold bag trader wash steamer fan cup water minute low pressure quick release perfection salt need butter else natural salt come kale swoon worthy heated water first saute high boil add top',
#  'update instant pot smart pot blue_tooth model',
#  'time',
#  'also purchase duo gift',
#  'love instant pot update',
#  'make beef beef soup perfect minute boneless pork rib perfectly cook hard_boiled egg minute manual high pressure cup water past day must say really impressed thing fast never use pressure cooker season slow cooker user',
#  'day meal cooking thing go put run mother year much',
#  'make life easy',
#  'quite simply good pressure cooker ever',
#  'wife love use often',
#  'difficult time digest meat cook thoroughly enough cooked meat pot cause issue godsend',
#  'improvement previous model thoughtful handy',
#  'truly winner far concerned',
#  '',
#  'year purchase hundred item get expect',
#  'never review',
#  'moment receive instant pot feel purchase exceeded_expectation make life easy delicious holistic low primal lifestyle food',
#  'many meal prepare require advance planning preparation ok realize investment family health wellbeing',
#  'look would support food choice perhaps make little less time consume',
#  'used crockpot extensively year appreciate ease ability put meal table soon get home evening taste factor run family',
#  'begin think way cook meal faster realize pressure cooker may answer',
#  'scared pressure cooker',
#  'even head tell people use many year problem heart say strong chance could blow entire kitchen include',
#  'electric programmable pressure cooker would virtually eliminate worry begin research first website',
#  'eventually purchase instant pot other stainless_steel insert aluminum size pot want large capacity ease',
#  'arrive plug begin read',
#  'manual helpful even include suggest trial run familiarize basic',
#  'meal potato soup know potato paleo get potato soup',
#  'make soup would normally take couple hour',
#  'coarsely chop vegetable throw pot add seasoning liquid start pressure cooker option minute immersion blender puree soup add cheese stir ready eat',
#  'soup bit good slow version keep tie kitchen stir monitor do',
#  'hide appliance cook food free thing harass kid get homework do',
#  'watch pot second recipe lemon pepper chicken wing',
#  'sear option first brown wing bit butter add lemon pepper salt tablespoon butter',
#  'put set pressure cooker minute come fall bone wing load flavor',
#  'family go wild also make flour minute pressure cooker good son eat top noodle next day lunch breakfast meat loaf cooker also winner',
#  'also use reheat food anymore finding seem easy make less mess go stovetop',
#  'pretty long review first tim enthusiastic product share',
#  'confirm',
#  'wonderful',
#  'silent',
#  'inner pot excellent quality stainless',
#  'love safe easy enough cook steel dress',
#  'great pot',
#  'receive instant pot right end year pre order',
#  'do good amount research previous model convince could replace small slow cooker diversify cook reduce time kitchen',
#  'main improvement like model previous model holder lid side handle pot large display main improvement interested dual pressure setting mainly come handy veggie',
#  'first take little get use new appliance',
#  'feature take get use pressure release valve electronic control',
#  'cook pressure cooker use traditional method necessary set pressure release valve close allow pressure build pot cooking',
#  'time forget twist pressure release valve close',
#  'eventually cause light whistle sound steam come release',
#  'twist well',
#  'read review give pot star_rating could tell closed pressure valve base result say achieve',
#  'use time remember shut valve',
#  'valve close second part find take get use control realize easy',
#  'truly set forget style people',
#  'close valve place hear electronic chime letting know lid closed easy hitting button label manual choosing amount time selector',
#  'allow follow recipe time',
#  'also hit pressure button adjust high low pressure',
#  'also whole bunch recipe slow cooker option convenient saut function use number time',
#  'second choose option cooker beep time pot start heat',
#  'make sure pressure release valve close take varying amount time pot heat usually minute pot create enough pressure push metal lock back unit prevent open pot pot safe pressure',
#  'set minute timer count pot letting know much time leave',
#  'keep mind take minute start finish cook minute cook time pressure cooker',
#  'sometimes seem happen listen carefully hear boil pot whenever cycle',
#  'time pot stay lock release pressure twisting pressure release valve waiting minute hour pressure release naturally',
#  'back open pot',
#  'feature love keep warm function',
#  'cook complete system automatically go keep warm',
#  'night forget pot cooking wake late night couch realize keep warm night press button keep warm function',
#  'stainless_steel cook pot easy clean however unit ease clean',
#  'love stainless_steel insert especially thick high quality',
#  'order second easily cook store variety different thing constantly clean move container food',
#  'take bit get use seemingly complex cooker little read manual great way experience able cook instant pot',
#  'start cook last year cook amazing soup chilie meat rice pastas vegetable first couple week look pressure setting run',
#  'high able well plan cook time',
#  'note many recipe find pressure cooking high add minute recipe',
#  'also live co add cook time due high altitude well',
#  'find good info use pressure cooking altitude',
#  'would highly_recommend pick food slicer instant pot well',
#  'dice onion celery carrot pineapple potato second instead minute help instant pot get stuff cook quick serve hot',
#  'slicer combination instant pot cut cook prep time third half would estimate case',
#  'get top rate borner slicer worth',
#  'importantly food taste amazing meat tender rice well cooked veggie incredible',
#  'would recommend pressure cooker market replacement slow cooker look cook quickly look eat healthy person access stove',
#  'plan purchase gift family future',
#  'order instant pot regret sooner amazing pot favorite appliance ever',
#  '',
#  'receive day ago already try recipe',
#  '',
#  '',
#  'first recipe braise cranberry wing instantpot laura site wing perfect',
#  '',
#  'try eggplant even hit fussy neighbor even apple upside cake',
#  'electric pressure cooker far impress even go stash appliance closet sure use often',
#  'little involve wonderful option still play bit get cover line lock use old cooker somewhat opposite get small price pay great appliance',
#  'old cooker white marking show lock pressure',
#  'steam',
#  'clean rub guess way',
#  'instant pot new good friend',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'mention get fence order soon stock get mine time run',
#  'awesomness pot',
#  'pot great quiet cook great lid redesign grip hand love easy handle click know seal also trimmer small trim make easy store think perfect pressure cooker instant pot ipduo',
#  'fence purchase instant pot previous version new feature irresistible',
#  'hold old model make fresh yogurt right planning make risotto',
#  'love instant pot easy risotto minute hard_boile egg steam bread_pudde much',
#  'great company keep food warm',
#  'use cuisinart multi cooker could roast pressure cooker function thing instant pot roast',
#  'also nonstick pot much prefer stainless_steel inner pot instant pot',
#  'think ever go back slow cooker',
#  'however slow cook instant pot',
#  'great luck cookbook add cooking time',
#  'new version instant pot',
#  'first pressure cooker',
#  'want year nightmare jiggly top cooker put purchase stove top pc',
#  'ideal pot beginner love may never advance stove top love much',
#  'use day get',
#  'make twice pot roast trimming make pear sauce cook green make broth tonight moroccan tangine mash turnip yam',
#  'get point hate cooking thrill eating',
#  'cook eat',
#  'recently start follow pressure cooker make easy',
#  'also love start dinner go walk dog cook',
#  'start take shower do right time ready eat breakfast',
#  'get run time',
#  'love',
#  'fun try different recipe',
#  'clean easy time consume',
#  'thank wonderful product',
#  'waited year afraid try use pressure cooker year warning explode',
#  'definitely recommendation instant pot',
#  '',
#  'slow cook pressure cook saute make yogurt deep fat fry cook frozen fish lobster minute',
#  'cook bean dry finished minute',
#  '',
#  'include give chart practically type food planet',
#  'excellent product could replace pot pan',
#  'also extra sealing gasket inner stainless_steel pot would like make multiple batch food serve liner pot',
#  '',
#  '',
#  'amazing tool cook almost food',
#  'cook practically even whole chicken come great',
#  'rice button accurate',
#  'soup work well',
#  'come book helpful get start',
#  '',
#  'new pressure cooking honestly know expect',
#  'finally choose give pressure cooking try look several model decide try',
#  'say',
#  'simple pot work flawlessly',
#  'already use several time single thing complain',
#  'maybe experience pressure cooking would critical believe perfect unit start',
#  'satisfied',
#  'much hope',
#  'purchase pressure cooker problem way much steam continuously escape valve',
#  'result loss sufficient liquid maintain pressure would shut',
#  'return second unit thing valve lid correctly',
#  'go read instant pot',
#  'work love unit',
#  'completely quiet',
#  'stainless_steel pot well cuisinart worried health reason',
#  'pot unit also large',
#  'plan buy second pot glass_lid store leftover dirty container cuisinart instant pot variety preset_button also set manually',
#  'work slow cooker steamer',
#  'far love unit make several soup cookbook specifically gear electric pressure cooker',
#  'beef stew minute well ever make slow cooker',
#  'wait experiment feature unit beat cuisinart hand',
#  'work excellent great steam veggie less minute',
#  'brown always come perfection make sure manual come',
#  'easy clean love amazing',
#  'take chance order pot online review',
#  'bit involved get hang process really easy',
#  'use make chicken fast wait try thing soup take unbelievably long normally',
#  'may update future',
#  '',
#  '',
#  'ship speed condition please quickly deliver item',
#  'package secure way could suffer damage',
#  'do frozen whole chicken edible hour',
#  'receive cooker week ago kid say almost everyday awesome',
#  'good review want come real person express love cooker',
#  'use slow cooker feature veggie steam couple time mostly pressure cooking',
#  'cook whole chicken minute minute finish skin day try yogurt yet',
#  'also come great way prepare deer breakfast sausage freeze',
#  '',
#  '',
#  '',
#  '',
#  'butcher paper put frozen block veggie steam basket pressure cook minute slice kind spam brown',
#  'work great',
#  'sure work uncooked tube sausage buy meat prefer naturally raise',
#  'buy version',
#  'wife love use frequently',
#  'cook time fast easy set program time',
#  'cool new cooker',
#  '',
#  'get yesterday make come',
#  'morning batch main reason buy pot',
#  'extremely happy easy pot',
#  'whenever pressure cook canned haul stool sit stove never take eye pressure gauge minute',
#  'instant pot first feel totally comfortable enough go day',
#  'highly_recommend look electric pressure cooker love',
#  'high rating remarkable product',
#  'culinary adventurer item cook',
#  'never use pressure cooker surprise easy intuitive control',
#  'feel really safe keep pressure cooking',
#  'also',
#  'set run store multitude household task list',
#  'back even finish keep warm ready plate serve',
#  'today pressure cooking adventure yield perfectly hard_boile egg easy peel shell',
#  'super fresh farm egg op struggle shell removal',
#  'fill white devil egg miss chunk look bad',
#  'problem today',
#  '',
#  '',
#  'shell slip right',
#  'recently buy insert remove item do start right away clean require',
#  'cheerful electronic lid lock chime time eat chime',
#  '',
#  '',
#  '',
#  'love product wish could justify buy',
#  'never own',
#  'regular pressure pan leak release much steam',
#  'always pressure last good',
#  'sure get electric research lot find',
#  'far satisfied wonderful pan',
#  'order base unbelievable high rating previous model amazon',
#  'truly amazing device instantly replace old rice cooker crock pot pressure cooker boot',
#  'compact programmable degree easy enough wife figure direction really rare gadget good advertise',
#  'actually good expect',
#  'normally cook instant pot make meal non stop month even try option incredibly easy safe reliable far less expensive eating',
#  'truly item purchase feel strongly enough write review',
#  'recommend highly enough',
#  'hope would',
#  'say wonderful product',
#  'make rice soup',
#  'product impress',
#  'bean set troublesome careful setting turn bean',
#  'significant associate product get hang worth money',
#  'instant pot ip duo',
#  'love truly pot cook saute onion brown meat finish casserole',
#  'make casserole uncooke pasta first time use',
#  'great overheat twice',
#  'guess problem hopefully eliminate get use use',
#  'reason rate star rather',
#  'make beef soup spectacular flavor',
#  'try week',
#  'easy',
#  'still learn',
#  'good ever buy able spend minimal amount time prepare ingredient wash chopping measure make meal half hour beat frozen boxed meal price health benefit',
#  'try many new recipe use instant pot couple time week purchase',
#  'make well meal less time save money cut process food',
#  'user_friendly',
#  'quiet traditional pressure cooker',
#  'feature instant pot work better expect',
#  'make dish pressure cooker mode',
#  'turn great flavorful',
#  'great pressure cooker',
#  '',
#  'far make garbanzo bean pot roast vegetable artichoke absolutely love',
#  'first dry bean want soak minute method explain instruction soak cook way take minute',
#  'vegetable cook wife agree taste can conventional method seem odd say garbanzo kidney bean',
#  'far quicker nice set come back beep do food',
#  'concern clean non issue stainless liner clean easily go fine',
#  'convert',
#  'much cook ruin meat admit',
#  'instant pot give hope use several time receive early',
#  'offer range tool simple complex',
#  'become totally familiar double check user manual try we great success',
#  'find cut meat add time cook need time',
#  'example take long recipe suggest',
#  'much well second day additional cooking',
#  'far good outcome chicken cacciatore beef stew',
#  'next chicken breast pork roast',
#  'expect successful',
#  'suggestion cut meat likely tough try use pressure cooker set recipe turn low slow set hour time think need',
#  'beef stew well second day reheat actually cook longer',
#  'think need experiment work best cut meat learn experience',
#  'buy thing far give great result',
#  'lot line',
#  'really saute feature recipe allow saute meat celery',
#  'add ingredient close lid set forget',
#  'thing remember allow get full pressure manually set timer',
#  'couple time think cooking discover let pressure',
#  'read user guide check online recipe',
#  'actually send sister need start eat healthy meal limited budget',
#  'say read instruction well use timer button instead adjust button',
#  'delay start cook time',
#  'set instant pot cook item manually require first set pressure',
#  'manually adjust time use adjust button',
#  'first second begin process need press cancel keep warm button start',
#  'great appliance update still star',
#  'use night get',
#  'make steamed',
#  'really easy easy clean',
#  'function admit get quite hot get pan stove get job do',
#  'take lot may concern people depend kind cabinet may fit say apartment cabinet especially type half shelf top back',
#  'recipe book come bit disappointment several recipe available turn provide urls site provide recipe find',
#  'instant pot company also extensive forum website',
#  'totally worth',
#  '',
#  'whole lot cooking pull time time',
#  'make shank base recipe come right',
#  'put ingredient turn instant pot really much',
#  'love steel cut oatmeal breakfast probably never cook',
#  'save minute major add ingredient let instant pot job get ready',
#  'stir burning',
#  'ready worry keep oatmeal warm',
#  '',
#  'soaking scrub need',
#  'follow principle recipe come pot give enough oatmeal last day',
#  'take oatmeal fridge morning minute',
#  'easy easy clean',
#  'instant pot fantastic',
#  'amazing fast cook love saute vegetable brown meat cook extra pot clean',
#  'make good mushroom risotto ever taste last night',
#  'sauteed onion pot throw rice mushroom stock easy minute cook time stir minute natural pressure release',
#  'way speed time start finish ingredient ice cold refrigerator possible',
#  'really cut time take bring full pressure',
#  'far make several dish come great',
#  'wonderful pot roast normally cook hour',
#  'cooked minute taste simmered hour',
#  'quick tender',
#  'whole come moist taste great',
#  'come many recipe find ton internet',
#  'definitely good kitchen appliance ever buy glad love even think would',
#  'purchase item',
#  'suppose',
#  'article',
#  'excellent product',
#  'buy primarily pressure cooker ever use stovetop pressure cooker likely disappoint',
#  'work take significantly longer regular stovetop pressure cooker',
#  'example make short rib night',
#  'normally would take minute stovetop pressure cooker',
#  'leave instant pot minute use natural pressure release method almost',
#  'hour cooking time',
#  'short good',
#  '',
#  'fall tender meaty one still tough dry',
#  'use make meat time even use meat setting time get result cook meat',
#  'keep pot crockpot rice maker fine',
#  'meat stew go back fagor quart pressure cooker',
#  'useful great pressure cooker',
#  '',
#  'divorce',
#  'cook never go fried hamburger helper get spectacular',
#  'write good thing true',
#  'ss pot meat button fine conflict recipe suggestion alter minute button',
#  'make first chuck roast pot roast ever fixing pot',
#  '',
#  'want try roast particular reason',
#  'tell really tough cut meat say know meat type',
#  'buy big cut half',
#  '',
#  'make half rump roast celery onion stuff',
#  'minute later complete dinner rump roast truly tender',
#  'month ago make soup',
#  'large instant pot make broth stove big pot',
#  'meat picking bag',
#  'time make soup take large frozen container turkey put instant pot set would defrost',
#  'minute',
#  'throw frozen meat corn niblet mushroom dice potato onion pepper stuff spice',
#  'set soup button deduct minute soup schedule accordance recipe',
#  'minute reach temperature cook delicous',
#  'minute make complicated soup dinner faster freeze pizza',
#  'machine',
#  'open whole new world cooking',
#  'beautiful new cooking dimension await',
#  'superior craftsmanship great time save device quality admire thing purchase',
#  'instant pot really deliver top notch appliance',
#  'lot line shopping item',
#  'long fear rumor danger use pressure cooker',
#  'nearly discourage information kitchen',
#  'seem electric pressure cooker',
#  'even use book cooker give excellent result',
#  '',
#  'easy make',
#  'easy way cook large batch potato make mashed_potatoe',
#  'cook uniformly easy process',
#  '',
#  'change buy cooker year ago',
#  'cook fast moist food keep food warm',
#  'kitchen amazing',
#  'purchase pressure cooker week ago probably use least time',
#  'love cook make life year old much easy',
#  'stew take hour really prep set go play baby',
#  'day make baked potato soup cream pumpkin soup hour',
#  'literally take potato',
#  'take still beat time nee watch stove pot',
#  'also must want make stock',
#  'make quart chicken stock hour smell look taste stock cooking half day',
#  'cook single day family big fan cooking year',
#  'believe never think purchase electric steamer never know exist recently',
#  'truly good kitchen appliance worth',
#  'amazing live',
#  'first pressure cooker can compare other',
#  'easy convenient expect',
#  'pop food push button time perfect braise',
#  'dish take hour do less hour',
#  'good heat',
#  'dish require fair amount liquid perfect start soup next day',
#  'convenient',
#  'good pressure cooker ever',
#  'quick heat quiet think work hiss loss steam quick release',
#  'easy clean good feature beautiful stainless_steel',
#  'wish instant pot would publish book recipe machine however use book problem',
#  'love thing',
#  'first purchase less expensive pressure cooker',
#  'read say coating flaking',
#  'send back make easy order instant pot brand',
#  'live stand alone kitchen device take long time pressure cooker thing many other talk afraid pressure cooker old experience hear horror_storie',
#  'favor time nutrient energy order instant pot good',
#  'really good cook everuthe short time recomend product worth perfect',
#  'far surpassed expectation try recipe function exactly expect',
#  'would highly_recommend would purchase gift',
#  'complain',
#  'regretted purchase slow cooker cooker yogurt maker separately',
#  'take precious space',
#  'nice look large work great',
#  '',
#  'love pot',
#  'use almost daily arrive',
#  'wish recipe cooking time show booklet',
#  'great',
#  'pressure cooker change',
#  'cut cook much many use list use daily love',
#  '',
#  'month update use product month feel proper update former comment become familiar feature',
#  'independent appraisal lot star rating',
#  'initial rating star',
#  'fair amount decide upgrade',
#  'really instantpot would recommend other',
#  'lot soup stew meal bowl dislike washing dish many year cook day wife want spend lot time kitchen',
#  'good mood undisputed speed queen fix meal',
#  'open can dump large saucepan little water seasoning minute later high heat voila almost scorch dinner',
#  'gal cooked meal may ticket enjoy cook preferred menu utilize pressure cook large extent live ft',
#  'elevation',
#  'must live',
#  'instant pot occupy small unused ledge corner kitchen',
#  'instant pot together would nicely fill space',
#  'main reason buy instantpot duo removable tri clad bottom mirror finish liner look chrome cook',
#  'set apart old time swisher type',
#  '',
#  '',
#  'add low pressure setting extend ability tender food',
#  'tender vegetable yogurt make feature differ non duo',
#  'make yet diabetic crisp veggie priority',
#  'sometime soon go try make',
#  'use several different mode enough feel comfortable offer little opinion',
#  'make stew brown meat pressure cook tender quickly add bean veggie put glass_lid set timer hour slow cook do',
#  'eat meal put entire steel pot leftover glass_lid must order separately fridge tomorrow day use single container use safe quiet clean appliance',
#  'ball cook whole chicken poultry set minute let depressurize',
#  'still pressure actually cook minute',
#  'remove little cartilage',
#  'set pot top barbecue hour cold solidify remove surface layer fat',
#  'put shred chicken piece back add veggie seasoning minute low pressure cooking slow cook do add freshly cook hot matzo ball serve',
#  'other say purchase extra liner glass_lid see would extend usability',
#  'liner really easy clean',
#  'rinse hot water soapy sponge rinse set sink basket dry',
#  'operation really quiet visible steam whooshing air',
#  'could easily cook dining room table small adjacent table',
#  'make pot bean next barbecue easy',
#  'set pose problem potential buyer add somewhat overall cooking time',
#  '',
#  '',
#  'reviewer remark big problem',
#  'actual high pressure set drop cook temp degree',
#  'low pressure',
#  'must add cooking time consideration',
#  'instance find preferable second electric',
#  '',
#  'tuck away kitchen corner use stove steam use barbeque convection electric pressure cooker go get big meal do even less time week nuke leftover',
#  'initially start program way wide_range different setting preset',
#  'second elapse start program can change stop reset',
#  'initial review complain little manual setting',
#  'come realize good percentage negative comment aside ship damage box person understand operation device',
#  '',
#  '',
#  '',
#  'guess different else misunderstood purpose manual program',
#  'manual pressure cook setting allow vary',
#  '',
#  'time',
#  'need change temp time pressure',
#  'find preset time suit',
#  'allow choose pressure time minute',
#  'really need manual add case find useful guess',
#  'rice set almost set way want book',
#  'pretty much want',
#  'could cook chicken use bean stew setting',
#  'instantpot police many setting take find various available combination',
#  'find combination cover basis',
#  'however easy stop run program switch different program enter new different time pressure temp',
#  'take maybe second',
#  'thing keep think box',
#  'go crazy creative rule probably would never even issue',
#  'ask wife',
#  'want pot beef stew ready get home sweat read manual encounter problem standard setting work fine',
#  'initial rating star think limited preset',
#  'turn really case',
#  'really want',
#  'matter evaluate perceive able',
#  'first preset seem absolute',
#  'matter little extra think button click',
#  '',
#  '',
#  'find preset work well many reviewer literally set forget',
#  'even heat tri clad bottom liner good feature greatly reduce instance eliminate entirely probability scorch food',
#  'preset setting seem work advertise part',
#  'suppose go cook thick sauce',
#  'preset temp often me',
#  'may high',
#  'first turn top setting able increase decrease temperature time pressure',
#  'thick may choose change temp med',
#  'low avoid scorching',
#  'slow cooking select saute high temp set save time order get quart soup mix boiling stop select slow cook reset time choose low slow temperature finish cooking',
#  'find good way cook pasta fill third full water select saute high temp water boil furiously stop reset temp medium finish cooking',
#  'may prove quick cook pasta stove also instantpot drain water add spice italian sausage meatball sauce slow cook low heat keep warm glass_lid dining room table leisurely pleasurable second helping get cold dining experience friend family',
#  'high temp want pressure cooking meat poultry inch water decrease startup time',
#  'minute use half inch water little water escape steam minute write first review pause go kitchen check quart cowboy slow cooking',
#  'almost time',
#  'decide need hour stop select slow cook medium temp reset time hour',
#  'program would automatically stop go keep warm mode start cook long',
#  'slow cook low chile gurgle away nicely scorch pot maxe inch top',
#  'even think fill pot full pressure cooking pot lin freezer half full frozen soup',
#  'put pot liner back place put glass_lid turn keep warm little hour',
#  'fully soup nice warm boot know would ever set keep warm tim hour forget swedish meatball serve warm fondue danger overheat boil away',
#  'speed bean pre soak put bean pot set keep warm hour let sit overnight',
#  'find necessary high dry climate',
#  'cook far turn way want little creative fiddling',
#  'new gadget require',
#  'many feature practice make perfect give instantpot designer credit automatic setting work well automate ease safety',
#  'cook science think art science',
#  'attend operation',
#  'tactile experience food preparation',
#  'slow cooking check time time make little adjustment',
#  '',
#  'time less heat add chicken stock taste oregano little paprika do do however long take',
#  'program work fine full automatic small exception may demand online flexibility',
#  'must admit biased often combine pressure cooking slow cooking',
#  'live foot humidity',
#  'store lot bean dry month',
#  'slow cook bean scratch take hour still do water boil degree',
#  'surprising difference make',
#  'bean much high moisture content degree do hour less',
#  'rapid make tea',
#  'pressure cooker great must higher altitude pressure pot regardless altitude',
#  'take little extra time bean use low pressure setting',
#  'especially delay auto shut keep warm feature',
#  'cook absolutely essential peace mind unattende operation know doze cooking late night',
#  'electric cooking appliance include induction range flameless time shutoff feature',
#  'retired time busy people go set forget ability instantpot may prove good feature',
#  'much instantpot use time week pot meal',
#  'use almost half year get pot bean cook',
#  'would say initial impression pretty close',
#  'thing especially like less pot pan use instantpot dislike washing pot pan',
#  'feature lead believe really try hit park',
#  'canadian distributor way go make want stand sing point big bugaboo manufacturer',
#  'add would fork little extra cash get totally perfect cooker',
#  'could test market top line',
#  '',
#  'believe people pay little know pay',
#  'desire convenience cooker price little competition',
#  'think great value',
#  'bottom line fine way',
#  'place kitchen',
#  '',
#  'hard beat',
#  'love cooker quiet easy easy',
#  'try feature yet would recommend',
#  'afraid pressure cooker',
#  'love cooker',
#  'easy',
#  'easy',
#  'enjoy recipe',
#  'meat vegetable bean good',
#  'go wrong',
#  'put ingredient go work arrive work dinner ready hot',
#  '',
#  'strong sucess home',
#  '',
#  'use',
#  'convenience efficiency',
#  'safe easy clean',
#  'love',
#  'buy',
#  'pressure cooker good',
#  '',
#  'pressure gas stove make nervous cooking wise let sight control',
#  'beauty however computer control safety mechanism',
#  'food cook quickly result delicious fry boiling',
#  'save money week make delicious greek yogurt half cost whole milk',
#  'save dish wild rice normally boil hour cooked minute perfection',
#  'easy enough put whole chicken pot push poultry button',
#  'do minute',
#  'model want make yogurt old less expensive one',
#  'save labor save nutient improve taste',
#  '',
#  'always run seam',
#  'love able come home grab frozen freeze cook',
#  'think instruction book need easy',
#  'spend lot time internet figure cook',
#  'even book come instant pot fantastic',
#  'experiment though',
#  'find need less water call grain water ratio really soft',
#  'also elevation nee add time cook',
#  'sure elevation effect recipe',
#  'high elevation add time',
#  'issue',
#  'rating book would give star',
#  'keep track work love',
#  'day jump hard boil egg finish put pork roast large pull throw quite potato',
#  'put whole right roast broth awesome',
#  'love',
#  '',
#  'use time great',
#  'easy simple',
#  'remove stainless_steel bowl cleaning wipe exterior do',
#  'saute cook pot',
#  'food turn great',
#  'still experiment lot recipe try',
#  'large family may want big one',
#  'quality product great',
#  'may want purchase glass_lid slow cooking option extra sealing_ring hand',
#  'great pressure cooker',
#  'pressure cooker good',
#  '',
#  '',
#  '',
#  '',
#  'star',
#  '',
#  '',
#  'safe easy get enough',
#  '',
#  '',
#  '',
#  'use almost everyday buy',
#  '',
#  '',
#  'buy favorite',
#  'pro work really well',
#  'congee brisket name',
#  '',
#  '',
#  'beautifully practically cooking smell pressure reach',
#  'stainless still insert',
#  'also small',
#  'stovetop pressure cooker great vegetable however pressure cooker great require supervision start extremely consistent',
#  'con beep loudly cook start end',
#  'think chinese recipe find translate instant pot website',
#  'also translate manual',
#  'still love instant pot still work perfectly buy early love highly recommend',
#  'pot great',
#  'kid love almost food cook',
#  'soup beef stew',
#  '',
#  '',
#  '',
#  'simple',
#  'learn technique change recipe suit taste',
#  'cook amazingly fast come pressure minute',
#  'throw gadget well build easy clean',
#  '',
#  'go appliance',
#  'want machine long time',
#  'finally save received wrong',
#  'obvious sign',
#  '',
#  '',
#  'burn smell',
#  'tell website',
#  'seriously talk live mail back forth take numerous picture decide fuse blow',
#  'send new fuse new bowl direction',
#  'replace',
#  'happen fuse blow',
#  'refuse send new machine',
#  'tell',
#  'quite problem consider various appliance use kitchen',
#  'refunded money problem appliance lemon take word',
#  'want give second chance price go way first order',
#  'want machine hesitant order know obstacle',
#  'problem',
#  'think may good cook ware ever purchase',
#  'update version well worth wait hear still improve',
#  '',
#  'use instant pot far chicken beef pork veggie quinoa',
#  'instruction manual great accurate time',
#  'would use less liquid quinoa still turn well',
#  'instant pot website fabulous recipe',
#  'love',
#  'instruction pot well design convenient judge safe',
#  'really change style cooking save time energy',
#  'make slightly large chuckwagon great pot',
#  'thing originally look slow cooker come instant pot amazon',
#  'use numerous time slow cooking rice maker pressure cooking',
#  'disappointment',
#  'buy see',
#  'great product',
#  'make pot roast',
#  'come delicious hour come pressure time',
#  'easy',
#  'love work great',
#  '',
#  'never use pressure cooker bit nervous try',
#  'love machine',
#  'use pressure cook high low many thing meat egg mashed_potatoe bean',
#  'really easy easy clean',
#  'use slow cook feature make',
#  'nice able set slow cook low certain amount time transition warm automatically',
#  'save overcook away home longer expect',
#  'saute feature really good browning meat setting cook',
#  'nice able pot',
#  'great product',
#  'fabulous stop pot use slow cooking brown meat cooking pressure cook little baby stainless clean beautifully love ship fast packaging perfect awesome',
#  'original lux',
#  'absolutely love decide second low pressure option',
#  'thing notice remain lid closed position',
#  'also function heating function saute lid place top',
#  'think change behavior model clearly state lid closed position able cooking function saute heating old lux work',
#  'dangerous part start saute even lid close lock',
#  'still check display issue old model warn close saute mode heat really turn',
#  'also quality control process seem dip item receive recede cancel warm button',
#  'can press push whole cooker back',
#  'also change bottom cushion rubber silicone make defect even pronounce silicone provide little grip kitchen cabinet slide place try press button',
#  'return',
#  'could receive bad item',
#  'comment insta pot duo set saute lid close lock could turn cooking option lid even place',
#  'new behavior return item instead ask replacement',
#  '',
#  '',
#  'good pressure cooker ever',
#  'great soup steam food',
#  '',
#  '',
#  'come recipe book',
#  '',
#  'thing get glad',
#  'pot amazing',
#  'perfect rice bean time',
#  'buy extra inside pot could make complete meal',
#  'easy',
#  'pot',
#  'duos ip lux',
#  'super easy read enough pressure cooker recipe may find use mostly manual setting',
#  'benefit extend speed ease meal preparation reduce energy main area interest',
#  'cook junk food want course',
#  'even remotely interested health find real treasure',
#  'prepare recipe need use good judgment',
#  'example long ago stop eat jam preserve usually unhealthy',
#  'see simple recipe pressure cooker decide give try',
#  'however cup berry perspective',
#  'work choose type pectin need end product go fresh home make yogurt example easily make ip duo version',
#  'versatile pot often mine several time day',
#  'barley put pot night may start day combine berry seed nuts fresh yogurt',
#  'black bean lentil soup black rice common choice',
#  'steam almost vegetable',
#  'breast spice make sandwich instead store buy luncheon meat avoid slow cooker type stew cook minute hearty vegetable stock freeze ball jar',
#  'range healthy possibility limited imagination',
#  'even dessert quite healthy',
#  'pudde brown black rice raisin dry berry little raw honey coconut cream example still treat quick make',
#  'good sense vary ingredient proportion need',
#  'thing can vouch durability own long enough',
#  'call make instant pot order arrive glass_lid result quick helpful response',
#  'update time',
#  'wonderful cooker',
#  'soon get pot start use stop love replace slow cooker finally give read instant pot many thing try',
#  'cook many thing pot include cheesecake turn great vegie cook mush well flavor',
#  'easy do instant pot bunch pan wash',
#  'brown meat pot slow cooking huge extra pan wash',
#  'say enough love use perfect pot',
#  'use time week perform practically pay make type stock chinese soup hour time saver modern woman kitchen secret weapon amazing',
#  'receive yesterday',
#  'cook curry white fish coconut recipe',
#  'come fantastic',
#  'eager see else',
#  'idea make pot meal meat veggie dish',
#  'far good',
#  'ability set start worth lot',
#  'peace mind ease make popular cooking',
#  'worth money',
#  'always afraid type pressure cooker use directly stave top aunt can red beet',
#  'good day',
#  '',
#  '',
#  'feel pot seem safe inexperienced',
#  'use time past week time work perfectly food absolutely divine',
#  'use recipe pressure cooker recipe purchase',
#  'excellent book ton practical recipe tip highly_recommend buy book pot together',
#  'pot',
#  'crock pot get bit radioactive crockpot gain crockpot superpower somehow',
#  'cook crockpot time',
#  'vegetarian taste many type bean kidney black',
#  'know cook stew make start smell burn hear run step swear breath',
#  'absentminde',
#  'bean take forever cook stove top even soak overnight',
#  'water evaporate',
#  'bean burn',
#  'buy speed cooking make automate',
#  'honestly pretty good cook',
#  'be little forgetful',
#  'claim cut cooking time degree people claim',
#  'cooking time see instruction set pressure cooker',
#  'much time cooker program pressure',
#  'take time pressure take time back high pressure keep mind tell people buy receive reaction',
#  'know thing super dangerous right think people refer stove top one',
#  'grant incredible amount potential energy pressure cooker',
#  'reference thing go',
#  '',
#  '',
#  'sound look realize s pound square inch',
#  'take scale measure square inch would need put pound little space',
#  'normal probably square foot area would square inch',
#  'would need balance large elephant lb get',
#  'probably make see poorly maintain pressure cooker dangerous',
#  'luckily thing easy follow maintenance instruction',
#  'greatly concerned blow',
#  'probably well point apparently type pressure cooker use make bomb see',
#  'find day greatly affect pressure cooking watchlist try board plane buy tell cook good hour little intrigue',
#  'easy',
#  'involve place type spice smoke paprika hot sauce vegie vegetable broth pan setting time come back do hour eat perhaps add additional veggie point crunchy rice recipe add rice add water set time minute release pressure minute',
#  'eat good rice eat home easy clean normal dirty do pop right',
#  'ton recipe follow start',
#  'website call real good',
#  'good general fastcooke',
#  '',
#  'cooker come easy follow recipe',
#  'make blackbean recipe time rice recipe make sweet burrito',
#  'tell forgetful know hard',
#  'really can burn water stay cooker food bean soak ton water presoake',
#  'forget bean thing hour',
#  'actual cooking time predetermine really low extra amount time',
#  'end result really mushy bean actually still pretty good',
#  'thing burn rice forget close pressure valve mean pressure cooking',
#  'pain clean let tell',
#  'soak water least hour could casually scrape burn rice trash',
#  'good thing ever',
#  'look stovetop stainless_steel pressure cooker tired pot electric one always wear get scratch cook essential suck come instant pot pot inside get attention never hear review positive decide give try far disappointed far good far good',
#  'top pressure cooker afraid wander',
#  'electric cooker perfect set forget cook food turn',
#  'reason choose instant pot pot want coat flake high pressure',
#  'easy also slow cooking make try plan',
#  'love cooker',
#  'week use time already',
#  'first large half split turkey_breast',
#  'use min',
#  'would work time',
#  '',
#  'fact cook cook skinless chicken thigh season broth dehydrate onion chop fresh carrot celery chicken base',
#  'do remove chicken chop cool bone',
#  'add milk half little butter adjust seasoning add chicken meat use thicken chicken biscuit',
#  'recently pork boneless shoulder',
#  '',
#  '',
#  '',
#  'pounder modify sweet baby ray',
#  'tender pork ever fix remember away home tender flavorful recommend pot enough instant pot ip duo programmable pressure cooker stainless',
#  '',
#  '',
#  '',
#  'first time use pressure cooker little nervous',
#  'tend pretty clumsy vision go wrong food explode everywhere laugh happen deep fry venture figure',
#  'turn worry naught',
#  'instruction well write proper include initial trial run procedure novice get feel machine',
#  'perfect trial run first dish beef stew',
#  'brown meat onion pot add little much water know next time toss coarsely chop garlic potato press meat stew button',
#  'machine choose correct time cook later cook time pot food',
#  'meat perfectly soft onion disappear sauce potato buttery soft cook whole thing overnight',
#  'officially sell gadget',
#  'great pressure cooker novice',
#  'meal scratch oven day perfect potato heat whole house',
#  'also find much easy steam green vegetable instant pot method',
#  'love life_changing',
#  'almost month love',
#  'get make sure read recipe idea differ standard stove top pressure cooker watch video could find',
#  'tend kitchen product buy know really want beforehand mistake avoid arrive',
#  'tonight last minute dinner idea toss frozen solid chicken leg thigh pour soy sauce vinegar press poultry button minute later perfectly cook flavorful adobo',
#  'instant pot probably would fast food instead',
#  'love thing',
#  '',
#  'believe traditional stove top pressure cooker difficult new one many update electric pressure cooker almost seem extravagant purchase',
#  '',
#  ...]

# %%
import pickle
with open('list_sentences_lemetised_B00FLYWNYQ.pkl', 'wb') as f:
    pickle.dump(list_sentences_lemetised, f)

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 1)]]

# %%
id2word[0]
# Out:
# 'cooker'

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.127*"love" + 0.122*"pot" + 0.075*"star" + 0.068*"instant" + 0.056*"great" '
#   '+ 0.049*"easy" + 0.032*"work" + 0.021*"size" + 0.020*"small" + '
#   '0.016*"little"'),
#  (1,
#   '0.056*"much" + 0.053*"well" + 0.046*"really" + 0.040*"meat" + '
#   '0.033*"amazing" + 0.021*"item" + 0.019*"sure" + 0.018*"crock" + '
#   '0.016*"worth" + 0.016*"instruction"'),
#  (2,
#   '0.069*"cook" + 0.068*"make" + 0.043*"good" + 0.037*"buy" + 0.030*"thing" + '
#   '0.029*"get" + 0.029*"product" + 0.026*"meal" + 0.021*"food" + 0.016*"come"'),
#  (3,
#   '0.077*"pressure" + 0.073*"cooker" + 0.047*"recipe" + 0.036*"take" + '
#   '0.034*"perfect" + 0.026*"fast" + 0.022*"first" + 0.021*"lot" + 0.019*"give" '
#   '+ 0.019*"people"'),
#  (4,
#   '0.091*"time" + 0.070*"use" + 0.042*"cooking" + 0.033*"would" + '
#   '0.029*"purchase" + 0.025*"slow" + 0.023*"try" + 0.021*"ever" + '
#   '0.021*"minute" + 0.021*"rice"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -6.686973335694573
#
# Coherence Score:  0.289322429787681

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.224406 -0.347491       1        1  28.606453
# 0      0.399882 -0.121178       2        1  24.739599
# 4     -0.075570  0.236889       3        1  19.507425
# 3     -0.051399  0.130616       4        1  16.418560
# 1     -0.048508  0.101164       5        1  10.727963, topic_info=         Term          Freq         Total Category  logprob  loglift
# 45       love  16710.000000  16710.000000  Default  30.0000  30.0000
# 67        pot  16014.000000  16014.000000  Default  29.0000  29.0000
# 26       time   9492.000000   9492.000000  Default  28.0000  28.0000
# 164      star   9925.000000   9925.000000  Default  27.0000  27.0000
# 169      cook  10552.000000  10552.000000  Default  26.0000  26.0000
# ...       ...           ...           ...      ...      ...      ...
# 584    pretty    469.182526    470.080780   Topic5  -4.8011   2.2304
# 534    arrive    450.178223    451.078888   Topic5  -4.8425   2.2303
# 1417       be    407.622864    408.515381   Topic5  -4.9418   2.2301
# 603   setting    410.114502    411.012726   Topic5  -4.9357   2.2301
# 783       pan    408.446381    409.356445   Topic5  -4.9398   2.2301
#
# [181 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 923       2  0.998629  absolutely
# 404       3  0.999137         add
# 330       1  0.999296      almost
# 698       3  0.998716     already
# 35        2  0.999384        also
# ...     ...       ...         ...
# 71        2  0.999828        work
# 688       5  0.998527       worth
# 29        3  0.999841       would
# 308       1  0.999447        year
# 277       1  0.998875      yogurt
#
# [151 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 1, 5, 4, 2])

# %% [markdown]
# ## LDA Mallet Model

# %%
mallet_path = 'mallet-2.0.8/bin/mallet' # update this path

# %%
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=5, id2word=id2word)

# Show Topics
pprint(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# 0- quality of cooking, 1-good appliance, 2-functionalities 3-product design, 5-how likely to recommend
# Out:
# [(0,
#   [('cook', 0.11880355478782645),
#    ('make', 0.11879219037661659),
#    ('minute', 0.03695706525444917),
#    ('rice', 0.030945291724435758),
#    ('meat', 0.024717594381435098),
#    ('chicken', 0.0238538991294861),
#    ('fast', 0.021115076027910993),
#    ('hour', 0.020637770757097076),
#    ('soup', 0.02012637225265359),
#    ('perfect', 0.019569516103370686)]),
#  (1,
#   [('time', 0.10477318103728467),
#    ('great', 0.08600315735710637),
#    ('work', 0.051933881227654737),
#    ('recipe', 0.0431234619492037),
#    ('meal', 0.04132423271579143),
#    ('appliance', 0.02143984770395134),
#    ('good', 0.02127733667641733),
#    ('week', 0.02097553048242559),
#    ('kitchen', 0.020244230858522543),
#    ('amazing', 0.020093327761526676)]),
#  (2,
#   [('cooker', 0.12109807905430366),
#    ('pressure', 0.11424085703731067),
#    ('cooking', 0.04832379017362394),
#    ('slow', 0.032704562246028815),
#    ('year', 0.017766438862209088),
#    ('steam', 0.01565386036202438),
#    ('set', 0.014730328777244181),
#    ('start', 0.013899150350942002),
#    ('function', 0.01388760620613225),
#    ('top', 0.01240995567048393)]),
#  (3,
#   [('easy', 0.0769973392356778),
#    ('good', 0.04890626103746262),
#    ('thing', 0.0444795026960842),
#    ('star', 0.04247804280769502),
#    ('food', 0.03782759189055546),
#    ('clean', 0.02491228896371471),
#    ('product', 0.014127952153335375),
#    ('small', 0.01243259789493513),
#    ('dish', 0.012397278014551791),
#    ('lid', 0.011690880406885021)]),
#  (4,
#   [('pot', 0.18378892212098027),
#    ('love', 0.1592242238760984),
#    ('instant', 0.09046857248846538),
#    ('buy', 0.057928172312258004),
#    ('star', 0.03481254781943382),
#    ('product', 0.03317799262711275),
#    ('purchase', 0.031242030094363684),
#    ('give', 0.015035589251350536),
#    ('recommend', 0.014548700470659155),
#    ('month', 0.013401034059029468)])]
#
# Coherence Score:  0.38239807846040713

# %%
ldamallet_3topics = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=3, id2word=id2word)

# Show Topics
pprint(ldamallet_3topics.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet_3topics, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(0,
#   [('great', 0.052320490367775835),
#    ('easy', 0.046183831421953564),
#    ('star', 0.04617676967402971),
#    ('work', 0.031580136715439806),
#    ('thing', 0.03024546635783289),
#    ('product', 0.0286848200666629),
#    ('recipe', 0.0262343935370883),
#    ('meal', 0.025139822608892155),
#    ('clean', 0.01494265860685837),
#    ('fast', 0.01310660414665838)]),
#  (1,
#   [('cook', 0.07052257737189244),
#    ('time', 0.061031625232538474),
#    ('make', 0.059793674953492304),
#    ('minute', 0.02199898528665652),
#    ('food', 0.021735159817351597),
#    ('rice', 0.018420429561982074),
#    ('cooking', 0.015646879756468796),
#    ('meat', 0.014713343480466767),
#    ('chicken', 0.014199222053103332),
#    ('hour', 0.012284796211736851)]),
#  (2,
#   [('pot', 0.11167940055987034),
#    ('love', 0.09637066503897343),
#    ('cooker', 0.07359699157388114),
#    ('pressure', 0.06944356745455438),
#    ('instant', 0.05475223281626009),
#    ('good', 0.03619512674257891),
#    ('buy', 0.033732539131288895),
#    ('slow', 0.019876098868332245),
#    ('purchase', 0.018907902029705402),
#    ('cooking', 0.013147832431787727)])]
#
# Coherence Score:  0.34834843293268847

# %%
ldamallet_4topics = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=4, id2word=id2word)

# Show Topics
pprint(ldamallet_4topics.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet_4topics, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# 0 - great product, 1- features and fucntions, 2-review after few days, 3-things to cook
# Out:
# [(0,
#   [('great', 0.06978783592644978),
#    ('easy', 0.06166902404526167),
#    ('good', 0.05798208392267798),
#    ('star', 0.04776991984912777),
#    ('work', 0.04218764733616219),
#    ('product', 0.038302687411598306),
#    ('recipe', 0.03503064592173503),
#    ('thing', 0.026053748231966052),
#    ('clean', 0.01995285242809995),
#    ('appliance', 0.017416313059877415)]),
#  (1,
#   [('cooker', 0.09646677889082061),
#    ('pressure', 0.09104874391735887),
#    ('time', 0.058411752260580804),
#    ('cooking', 0.03851496168740974),
#    ('slow', 0.0260599203392481),
#    ('steam', 0.012473438750448436),
#    ('set', 0.011737542658976552),
#    ('function', 0.01105683877436506),
#    ('start', 0.010790076441206501),
#    ('long', 0.01029334657946298)]),
#  (2,
#   [('pot', 0.14967841426260955),
#    ('love', 0.1291138526347463),
#    ('instant', 0.07338172791213751),
#    ('buy', 0.04698724940760522),
#    ('purchase', 0.025313122954827547),
#    ('day', 0.017329898070485576),
#    ('thing', 0.01700078985970587),
#    ('week', 0.016991386767969307),
#    ('star', 0.014527776732989807),
#    ('year', 0.01447135818257043)]),
#  (3,
#   [('cook', 0.09445501862760132),
#    ('make', 0.09429264728433928),
#    ('meal', 0.03211344344515908),
#    ('minute', 0.029335089349341946),
#    ('food', 0.02898328477227419),
#    ('rice', 0.024563175983474204),
#    ('time', 0.024157247625319105),
#    ('meat', 0.0196198706441632),
#    ('chicken', 0.018934302750390142),
#    ('hour', 0.01638146440910362)])]
#
# Coherence Score:  0.3795423515389911

# %%
ldamallet_6topics = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=6, id2word=id2word)
# Out:
# [(0,
#   [('great', 0.052320490367775835),
#    ('easy', 0.046183831421953564),
#    ('star', 0.04617676967402971),
#    ('work', 0.031580136715439806),
#    ('thing', 0.03024546635783289),
#    ('product', 0.0286848200666629),
#    ('recipe', 0.0262343935370883),
#    ('meal', 0.025139822608892155),
#    ('clean', 0.01494265860685837),
#    ('fast', 0.01310660414665838)]),
#  (1,
#   [('cook', 0.07052257737189244),
#    ('time', 0.061031625232538474),
#    ('make', 0.059793674953492304),
#    ('minute', 0.02199898528665652),
#    ('food', 0.021735159817351597),
#    ('rice', 0.018420429561982074),
#    ('cooking', 0.015646879756468796),
#    ('meat', 0.014713343480466767),
#    ('chicken', 0.014199222053103332),
#    ('hour', 0.012284796211736851)]),
#  (2,
#   [('pot', 0.11167940055987034),
#    ('love', 0.09637066503897343),
#    ('cooker', 0.07359699157388114),
#    ('pressure', 0.06944356745455438),
#    ('instant', 0.05475223281626009),
#    ('good', 0.03619512674257891),
#    ('buy', 0.033732539131288895),
#    ('slow', 0.019876098868332245),
#    ('purchase', 0.018907902029705402),
#    ('cooking', 0.013147832431787727)])]
#
# Coherence Score:  0.41796728833348235

# %%
# Show Topics
pprint(ldamallet_6topics.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet_6topics, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(0,
#   [('pot', 0.2254961680667507),
#    ('love', 0.194585712059611),
#    ('instant', 0.11055233670014591),
#    ('easy', 0.09264637135045543),
#    ('clean', 0.029975492626538792),
#    ('crock', 0.013344477341304133),
#    ('size', 0.011616211698375147),
#    ('stainless_steel', 0.011460384468274992),
#    ('big', 0.01143205224462042),
#    ('large', 0.011262058902692978)]),
#  (1,
#   [('make', 0.14264075762124395),
#    ('minute', 0.04437651810813024),
#    ('rice', 0.0371578286618815),
#    ('meat', 0.029679866815862013),
#    ('chicken', 0.02864277721677902),
#    ('cook', 0.026773286755274146),
#    ('hour', 0.024780983051772603),
#    ('soup', 0.024166916841789253),
#    ('perfect', 0.02349826696869627),
#    ('bean', 0.02098741846565323)]),
#  (2,
#   [('cooker', 0.14178358067742547),
#    ('pressure', 0.13378206687751737),
#    ('slow', 0.03829102803233044),
#    ('cooking', 0.028099910793933987),
#    ('steam', 0.01832779174438407),
#    ('function', 0.015962479387992324),
#    ('top', 0.01452977590354932),
#    ('lid', 0.013421458113697186),
#    ('feature', 0.012934879571810883),
#    ('saute', 0.010731760062714568)]),
#  (3,
#   [('good', 0.0866568956283999),
#    ('thing', 0.056667324332703856),
#    ('recipe', 0.05235491417458215),
#    ('star', 0.02843935849375687),
#    ('appliance', 0.026029482228924154),
#    ('purchase', 0.025522139857380423),
#    ('kitchen', 0.024577919332562925),
#    ('amazing', 0.024281969615829083),
#    ('lot', 0.023281377716395615),
#    ('buy', 0.02302770653062375)]),
#  (4,
#   [('great', 0.10388681679239463),
#    ('star', 0.06440169382203652),
#    ('work', 0.06273311085560447),
#    ('product', 0.05695616814829356),
#    ('buy', 0.047154995933705375),
#    ('year', 0.021579404918814323),
#    ('recommend', 0.017597240528337867),
#    ('month', 0.016209091673911213),
#    ('item', 0.01504529010908887),
#    ('review', 0.013110294736251717)]),
#  (5,
#   [('time', 0.1256003675293397),
#    ('cook', 0.1184586042238031),
#    ('meal', 0.049546853030028815),
#    ('food', 0.044729991229413485),
#    ('cooking', 0.02934666091241943),
#    ('fast', 0.025866269437986384),
#    ('day', 0.0256574459495204),
#    ('week', 0.025156269577202045),
#    ('dinner', 0.01776391808550626),
#    ('quick', 0.016845094736255933)])]
#
# Coherence Score:  0.41796728833348235

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values
# Out:
# [(0,
#   [('hot', 0.1900320123633955),
#    ('coffee', 0.17303234352577548),
#    ('hour', 0.09222872281708798),
#    ('drink', 0.05571807042719947),
#    ('cold', 0.03896677337454465),
#    ('warm', 0.038828789049563966),
#    ('long', 0.036317474334915556),
#    ('day', 0.033916547080251686),
#    ('stay', 0.024781984766530523),
#    ('tea', 0.02100121426205983)]),
#  (1,
#   [('lid', 0.04567095750308588),
#    ('clean', 0.038382413448539356),
#    ('easy', 0.027067536589666725),
#    ('put', 0.026538529359901253),
#    ('top', 0.025216011285487568),
#    ('make', 0.021542349967671782),
#    ('seal', 0.020837006994651148),
#    ('paint', 0.018074413683653676),
#    ('hand', 0.014430141656380416),
#    ('color', 0.011843884088638101)]),
#  (2,
#   [('good', 0.08141759632649456),
#    ('travel', 0.06013599034527419),
#    ('great', 0.057104170959291205),
#    ('buy', 0.04998086715921467),
#    ('love', 0.04950990492449887),
#    ('star', 0.04653695581785536),
#    ('product', 0.037824154475612985),
#    ('thermo', 0.034497983692932624),
#    ('mug', 0.028993612574691668),
#    ('year', 0.021458216819238807)]),
#  (3,
#   [('leak', 0.05098130977799877),
#    ('work', 0.05048407382491445),
#    ('open', 0.031530609260288396),
#    ('thing', 0.02816695428354149),
#    ('close', 0.028108455936119804),
#    ('time', 0.02609026295007166),
#    ('spill', 0.024189066658866887),
#    ('proof', 0.021205650940360934),
#    ('cup', 0.01579455380385504),
#    ('nice', 0.015326567024481558)])]
#
# Coherence Score:  0.4217769271493862

# %%
## Finding DOminant Topi in each Sentence

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_lemmatized):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamallet_6topics, corpus=corpus, texts=data_lemmatized)

# %%
# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
# Out:
# (116456, 5)

# %%
# Show
df_dominant_topic
# Out:
#         Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0                 0             2.0              0.1950
# 1                 1             3.0              0.2063
# 2                 2             1.0              0.1879
# 3                 3             5.0              0.1944
# 4                 4             2.0              0.1830
# ...             ...             ...                 ...
# 116451       116451             3.0              0.1950
# 116452       116452             0.0              0.1914
# 116453       116453             4.0              0.1830
# 116454       116454             0.0              0.2241
# 116455       116455             4.0              0.1795
#
#                                                  Keywords  \
# 0       cooker, pressure, slow, cooking, steam, functi...
# 1       good, thing, recipe, star, appliance, purchase...
# 2       make, minute, rice, meat, chicken, cook, hour,...
# 3       time, cook, meal, food, cooking, fast, day, we...
# 4       cooker, pressure, slow, cooking, steam, functi...
# ...                                                   ...
# 116451  good, thing, recipe, star, appliance, purchase...
# 116452  pot, love, instant, easy, clean, crock, size, ...
# 116453  great, star, work, product, buy, year, recomme...
# 116454  pot, love, instant, easy, clean, crock, size, ...
# 116455  great, star, work, product, buy, year, recomme...
#
#                                                      Text
# 0         [first, pressure, cooker, really, sure, expect]
# 1       [say, find, intuitive, easy, make, sure, read,...
# 2             [try, decide, start, simple, bake, chicken]
# 3       [product, come, recommend, cooking, time, vari...
# 4                                           [would, lose]
# ...                                                   ...
# 116451                             [buy, small, everyday]
# 116452                    [wonderful, big, perfect, size]
# 116453                                            [great]
# 116454  [love, due, mini, fun, perfect, size, single, ...
# 116455                                [great, applicance]
#
# [116456 rows x 5 columns]

# %% [markdown]
# ## Sentiment Analysis using Text Blob

# %%
from textblob import TextBlob
# Get the polarity score using below function
def get_textBlob_score(sent):
    # This polarity score is between -1 to 1
    polarity = TextBlob(sent).sentiment.polarity
    return polarity

# %%
len(list_sentences_lemetised)
# Out:
# 116456

# %%
# Prepare sentiment scores for all sentences from text blob
texblog_senti_scores= []
for sentence in list_sentences_lemetised:
    texblog_score = get_textBlob_score(sentence)
    texblog_senti_scores.append(texblog_score)

# %%
len(texblog_senti_scores)
# Out:
# 116456

# %%
texblog_senti_scores[20000], list_sentences_lemetised[20000]
# Out:
# (0.0, 'also prepare meal pot night meat custom broth mix')

# %% [markdown]
# ## Combine Sentiment Analysis with LDA

# %%
df_full['topics'] = df_dominant_topic['Dominant_Topic'].astype(float)

# %%
df_full['sentiment_scores'] = np.resize(texblog_senti_scores,len(df_full))
# Out:
#         overall      reviewerID        asin  \
# 0           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 1           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 2           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 3           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 4           5.0  A38QLFND44V8QG  B00FLYWNYQ
# ...         ...             ...         ...
# 116451      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116452      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116453      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116454      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
# 116455      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
#
#                                                reviewText   rev_date  \
# 0       This is my first pressure cooker so I wasn't r... 2014-01-04
# 1       This is my first pressure cooker so I wasn't r... 2014-01-04
# 2       This is my first pressure cooker so I wasn't r... 2014-01-04
# 3       This is my first pressure cooker so I wasn't r... 2014-01-04
# 4       This is my first pressure cooker so I wasn't r... 2014-01-04
# ...                                                   ...        ...
# 116451  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116452  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116453  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116454  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
# 116455  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
#
#                                                 sentences  sentiment_scores
# 0       This is my first pressure cooker so I wasn't r...          0.375000
# 1         That being said, I found it very intuitive a...          0.466667
# 2         To try it out I decided to start with someth...         -0.300000
# 3         This product comes with recommended cooking ...          0.300000
# 4                       I would have been lost without it          0.000000
# ...                                                   ...               ...
# 116451    I bought the smaller one for everyday since ...         -0.225000
# 116452    It's just as wonderful as the bigger one, bu...          0.666667
# 116453                                      //Great for 2          0.800000
# 116454  I love my Due Mini!  It is fun to use--and it ...          0.225595
# 116455                                //Great Applicance!          0.800000
#
# [116456 rows x 7 columns]

# %%
df_full
# Out:
#         overall      reviewerID        asin  \
# 0           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 1           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 2           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 3           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 4           5.0  A38QLFND44V8QG  B00FLYWNYQ
# ...         ...             ...         ...
# 116451      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116452      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116453      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116454      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
# 116455      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
#
#                                                reviewText   rev_date  \
# 0       This is my first pressure cooker so I wasn't r... 2014-01-04
# 1       This is my first pressure cooker so I wasn't r... 2014-01-04
# 2       This is my first pressure cooker so I wasn't r... 2014-01-04
# 3       This is my first pressure cooker so I wasn't r... 2014-01-04
# 4       This is my first pressure cooker so I wasn't r... 2014-01-04
# ...                                                   ...        ...
# 116451  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116452  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116453  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116454  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
# 116455  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
#
#                                                 sentences  sentiment_scores  \
# 0       This is my first pressure cooker so I wasn't r...          0.375000
# 1         That being said, I found it very intuitive a...          0.466667
# 2         To try it out I decided to start with someth...         -0.300000
# 3         This product comes with recommended cooking ...          0.300000
# 4                       I would have been lost without it          0.000000
# ...                                                   ...               ...
# 116451    I bought the smaller one for everyday since ...         -0.225000
# 116452    It's just as wonderful as the bigger one, bu...          0.666667
# 116453                                      //Great for 2          0.800000
# 116454  I love my Due Mini!  It is fun to use--and it ...          0.225595
# 116455                                //Great Applicance!          0.800000
#
#         topics
# 0          2.0
# 1          3.0
# 2          1.0
# 3          5.0
# 4          2.0
# ...        ...
# 116451     3.0
# 116452     0.0
# 116453     4.0
# 116454     0.0
# 116455     4.0
#
# [116456 rows x 8 columns]

# %%
df_full['sentiment_scores'].describe()
# Out:
# count    116456.000000
# mean          0.179585
# std           0.301609
# min          -1.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.400000
# max           1.000000
# Name: sentiment_scores, dtype: float64

# %%
texblog_senti_scores
sentiments_textblob = []
for each in texblog_senti_scores:
    if(each >=0.4):
        a=1
    else:
        a=0
    sentiments_textblob.append(a)

# %%
df_full['sentiment'] = np.resize(sentiments_textblob,len(df_full))

# %%
df_full
# Out:
#         overall      reviewerID        asin  \
# 0           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 1           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 2           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 3           5.0  A38QLFND44V8QG  B00FLYWNYQ
# 4           5.0  A38QLFND44V8QG  B00FLYWNYQ
# ...         ...             ...         ...
# 116451      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116452      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116453      5.0  A27HMTTTL9X72A  B00FLYWNYQ
# 116454      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
# 116455      5.0  A2KXZ2A335QDI8  B00FLYWNYQ
#
#                                                reviewText   rev_date  \
# 0       This is my first pressure cooker so I wasn't r... 2014-01-04
# 1       This is my first pressure cooker so I wasn't r... 2014-01-04
# 2       This is my first pressure cooker so I wasn't r... 2014-01-04
# 3       This is my first pressure cooker so I wasn't r... 2014-01-04
# 4       This is my first pressure cooker so I wasn't r... 2014-01-04
# ...                                                   ...        ...
# 116451  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116452  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116453  I bought the 8 Qt first and use it a lot for m... 2018-07-21
# 116454  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
# 116455  I love my Due Mini!  It is fun to use--and it ... 2018-07-21
#
#                                                 sentences  sentiment_scores  \
# 0       This is my first pressure cooker so I wasn't r...          0.375000
# 1         That being said, I found it very intuitive a...          0.466667
# 2         To try it out I decided to start with someth...         -0.300000
# 3         This product comes with recommended cooking ...          0.300000
# 4                       I would have been lost without it          0.000000
# ...                                                   ...               ...
# 116451    I bought the smaller one for everyday since ...         -0.225000
# 116452    It's just as wonderful as the bigger one, bu...          0.666667
# 116453                                      //Great for 2          0.800000
# 116454  I love my Due Mini!  It is fun to use--and it ...          0.225595
# 116455                                //Great Applicance!          0.800000
#
#         topics  sentiment
# 0          2.0          0
# 1          3.0          1
# 2          1.0          0
# 3          5.0          0
# 4          2.0          0
# ...        ...        ...
# 116451     3.0          0
# 116452     0.0          1
# 116453     4.0          1
# 116454     0.0          0
# 116455     4.0          1
#
# [116456 rows x 9 columns]

# %%
topic_wise_sentiment_counts = df_full.groupby(['topics'])['sentiment'].value_counts()
topic_wise_sentiment_counts
# Out:
# topics  sentiment
# 0.0     0            33481
#         1             9182
# 1.0     0            10889
#         1             3858
# 2.0     0            11749
#         1             3004
# 3.0     0            10042
#         1             5700
# 4.0     0            11639
#         1             5502
# 5.0     0             9128
#         1             2282
# Name: sentiment, dtype: int64

# %%
total_sentiment = df_full.groupby(['topics'])['sentiment'].count()
total_sentiment
# Out:
# topics
# 0.0    42663
# 1.0    14747
# 2.0    14753
# 3.0    15742
# 4.0    17141
# 5.0    11410
# Name: sentiment, dtype: int64

# %%
total_sentiment.loc[0], topic_wise_sentiment_counts[0][1]
# Out:
# (42663, 9182)

# %%
results = []
ratings= []
for i in range(6):
    value = total_sentiment.loc[i]/topic_wise_sentiment_counts[i][1]
    results.append(value)
    if (value >4):
        ratings.append(5)
    elif (value >3):
        ratings.append(4)
    elif (value >2):
        ratings.append(3)
    elif (value >1):
        ratings.append(2)
    else: ratings.append(1)
results, ratings
# Out:
# ([4.646373339141799,
#   3.8224468636599274,
#   4.911118508655126,
#   2.7617543859649123,
#   3.1154125772446384,
#   5.0],
#  [5, 4, 5, 3, 4, 5])

# %% [markdown]
# ## Results

# %% [markdown]
# ### Topic wise product rating

# %%
Product_Summary = pd.DataFrame({'productID':['B00FLYWNYQ', 'B00FLYWNYQ', 'B00FLYWNYQ', 'B00FLYWNYQ', 'B00FLYWNYQ', 'B00FLYWNYQ'],
                              'topic': ['Product Design', 'What to Cook', 'Product Features', 'Likely Recommendation', 'recommendation', 'Time to cook'],
                               'rating': ratings})
Product_Summary
# Out:
#     productID                  topic  rating
# 0  B00FLYWNYQ         Product Design       5
# 1  B00FLYWNYQ           What to Cook       4
# 2  B00FLYWNYQ       Product Features       5
# 3  B00FLYWNYQ  Likely Recommendation       3
# 4  B00FLYWNYQ         recommendation       4
# 5  B00FLYWNYQ           Time to cook       5

# %% [markdown]
# ### Most Postive sentences for this product

# %%
df_full.nlargest(5, 'sentiment_scores')['sentences']
# Out:
# 90     \n\nI'm really impressed with the quality of t...
# 94       Both dishes I tested which were  brown rice ...
# 98                            The brown rice was perfect
# 149                                            Wonderful
# 245                    Thank you for a wonderful product
# Name: sentences, dtype: object

# %%
df_full.iloc[90]['sentences']
# Out:
# "\n\nI'm really impressed with the quality of this cooker!  It feels and looks like it was very well thought out and constructed"

# %%
df_full.iloc[94]['sentences']
# Out:
# '  Both dishes I tested which were  brown rice and Ossobuco turned out delicious'

# %%
df_full.iloc[98]['sentences']
# Out:
# '  The brown rice was perfect'

# %%
df_full.iloc[149]['sentences']
# Out:
# 'Wonderful'

# %%
df_full.iloc[245]['sentences']
# Out:
# '  Thank you for a wonderful product'

# %% [markdown]
# ### Most negative sentences for this product

# %%
df_full.nsmallest(5, 'sentiment_scores')['sentences']
# Out:
# 1153     Tried to make yogurt 3 times and it turned out...
# 3006       Anybody who has worked with plastic before k...
# 7640      I ended up discarding the rice pudding, it wa...
# 9565      Only reason not a 5 star\nThe manual's cookin...
# 10951    \nWhy? The terrible silicone ring that absorbe...
# Name: sentences, dtype: object

# %%
df_full.iloc[1153]['sentences']
# Out:
# 'Tried to make yogurt 3 times and it turned out awful, grainey and watery'

# %%
df_full.iloc[3006]['sentences']
# Out:
# '  Anybody who has worked with plastic before knows that plastic has a nasty habit of letting things penetrate inside'

# %%
df_full.iloc[7640]['sentences']
# Out:
# ' I ended up discarding the rice pudding, it was that awful'

# %%
df_full.iloc[9565]['sentences']
# Out:
# " Only reason not a 5 star\nThe manual's cooking times and water mix are terrible"

# %%
df_full.iloc[10951]['sentences']
# Out:
# "\nWhy? The terrible silicone ring that absorbed food smell, and even the detergent's smell when I tried to wash it, and the mixture made me ditch the pot"
