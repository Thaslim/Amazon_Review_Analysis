# %%
import pandas as pd
import pickle
import gzip
import json

# %%
#Code adapted from the datasource http://jmcauley.ucsd.edu/data/amazon/
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %%
#Convert json to pd dataframe
df = getDF('Home_and_Kitchen_5.json.gz')

# %%
#Check datatype and information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6898955 entries, 0 to 6898954
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   overall         float64
#  1   verified        bool
#  2   reviewTime      object
#  3   reviewerID      object
#  4   asin            object
#  5   reviewerName    object
#  6   reviewText      object
#  7   summary         object
#  8   unixReviewTime  int64
#  9   vote            object
#  10  style           object
#  11  image           object
# dtypes: bool(1), float64(1), int64(1), object(9)
# memory usage: 638.2+ MB

# %%
#Visualize the data
df
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 0            5.0      True   11 5, 2015   A8LUWTIPU9CZB  0560467893
# 1            3.0      True   05 7, 2015  A3B6GKQQ1JJ167  0560467893
# 2            5.0      True  01 22, 2014  A3MCTN65BU7XRA  0681795107
# 3            1.0      True  10 30, 2013   A7JVZFSXVY9RL  0681795107
# 4            1.0      True  09 20, 2013  A2RQ7VLAK1SHPU  0681795107
# ...          ...       ...          ...             ...         ...
# 6898950      5.0      True   08 8, 2016   AB4CZUDHN52H5  B01HJEJDBQ
# 6898951      2.0      True   09 5, 2017  A12NA9GEGY6I3E  B01HJEOT2E
# 6898952      4.0      True  07 30, 2017  A38PQCNDGGWSPQ  B01HJEOT2E
# 6898953      4.0      True  07 28, 2018  A2AY2C5EW8VOO7  B01HJGJNWS
# 6898954      5.0      True  07 22, 2018   A53HGFV9H8A5F  B01HJGJNWS
#
#             reviewerName                                         reviewText  \
# 0           Linda Fahner                           Great product, love it!!
# 1        Harry Slaughter  Pretty flimsy, but does the job. If your corne...
# 2                 luckyg  So much better than plastic mug types--keeps c...
# 3               Nickleen  I like my coffee hot; borderline scorching but...
# 4           Lacemaker427  This mug does only a fair job of keeping coffe...
# ...                  ...                                                ...
# 6898950         J. Mayer  I purchased these as decorations for my classr...
# 6898951           Loreli  getting the used tea leaves out of this is ext...
# 6898952            Becca  Good deal. It took a while to recieve so I kin...
# 6898953      Dr. Quinzel  Great price and okay quality. I know it's not ...
# 6898954           Simone  Lightweight and roomy. Perfect for Sunday roasts!
#
#                                               summary  unixReviewTime vote  \
# 0                                          Five Stars      1446681600  NaN
# 1                                                 Meh      1430956800    2
# 2                                           Recommend      1390348800  NaN
# 3              Not keeping coffee hot for long enough      1383091200  NaN
# 4            Leaks like a waterfall when at an angle!      1379635200  NaN
# ...                                               ...             ...  ...
# 6898950                            Beautiful Pom poms      1470614400  NaN
# 6898951                  cute but not very functional      1504569600  NaN
# 6898952  Good deal. It took a while to recieve so ...      1501372800  NaN
# 6898953                                    Four Stars      1532736000  NaN
# 6898954                     Perfect for Sunday roasts      1532217600  NaN
#
#                                           style image
# 0                                           NaN   NaN
# 1                                           NaN   NaN
# 2              {'Color:': ' Brushed Stainless'}   NaN
# 3              {'Color:': ' Brushed Stainless'}   NaN
# 4                            {'Color:': ' Red'}   NaN
# ...                                         ...   ...
# 6898950  {'Color:': ' Mint Green/Purple/White'}   NaN
# 6898951                     {'Color:': ' Blue'}   NaN
# 6898952                     {'Color:': ' Blue'}   NaN
# 6898953                    {'Color:': ' Black'}   NaN
# 6898954                    {'Color:': ' Black'}   NaN
#
# [6898955 rows x 12 columns]

# %% [markdown]
# ## Data Preparation and Cleaning
# #### 1. The column name 'vote','style','image' does not provide much information for this project and 'reviewerName' is not required since the dataset contains 'reviewer id'
# #### 2. Drop all the unverified reviews
# #### 3. Conver reviewtime to date format
# #### 4. Find all duplicate entries (I.e If the reviewer has reviewed the same product more than once, Keep the latest review)
# #### 5. Check for null values remove entries where both summary and reviewtext are nan
# #### 6. Find all the url in summary text and replace them with ''
# #### 7. Combine Review text and summary column and drop summary column and reset index
# #### 8. Find all the url in review text and remove
# #### 9. Check for null values
# #### 10. Save pickle file

# %%
#Drop columns that are not required for analysis
df.drop(columns=['vote','style','image','reviewerName'],inplace=True)

# %%
#View top 5 rows
df.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0      5.0      True   11 5, 2015   A8LUWTIPU9CZB  0560467893
# 1      3.0      True   05 7, 2015  A3B6GKQQ1JJ167  0560467893
# 2      5.0      True  01 22, 2014  A3MCTN65BU7XRA  0681795107
# 3      1.0      True  10 30, 2013   A7JVZFSXVY9RL  0681795107
# 4      1.0      True  09 20, 2013  A2RQ7VLAK1SHPU  0681795107
#
#                                           reviewText  \
# 0                           Great product, love it!!
# 1  Pretty flimsy, but does the job. If your corne...
# 2  So much better than plastic mug types--keeps c...
# 3  I like my coffee hot; borderline scorching but...
# 4  This mug does only a fair job of keeping coffe...
#
#                                     summary  unixReviewTime
# 0                                Five Stars      1446681600
# 1                                       Meh      1430956800
# 2                                 Recommend      1390348800
# 3    Not keeping coffee hot for long enough      1383091200
# 4  Leaks like a waterfall when at an angle!      1379635200

# %%
#Check for the unique values in verified column
df.verified.unique()
# Out:
# array([ True, False])

# %%
#Drop all the unverified reviews
drp_ind = df[df['verified']==False].index
df.drop(drp_ind,inplace=True)

# %%
#Covert unixReview time to date date format and add a column 'rev_date'
df['rev_date'] = pd.to_datetime(df.unixReviewTime,unit = 's')

# %%
#drop unwanted columns
df.drop(columns=['reviewTime','unixReviewTime','verified'],inplace=True)

# %%
df
# Out:
#          overall      reviewerID        asin  \
# 0            5.0   A8LUWTIPU9CZB  0560467893
# 1            3.0  A3B6GKQQ1JJ167  0560467893
# 2            5.0  A3MCTN65BU7XRA  0681795107
# 3            1.0   A7JVZFSXVY9RL  0681795107
# 4            1.0  A2RQ7VLAK1SHPU  0681795107
# ...          ...             ...         ...
# 6898950      5.0   AB4CZUDHN52H5  B01HJEJDBQ
# 6898951      2.0  A12NA9GEGY6I3E  B01HJEOT2E
# 6898952      4.0  A38PQCNDGGWSPQ  B01HJEOT2E
# 6898953      4.0  A2AY2C5EW8VOO7  B01HJGJNWS
# 6898954      5.0   A53HGFV9H8A5F  B01HJGJNWS
#
#                                                 reviewText  \
# 0                                 Great product, love it!!
# 1        Pretty flimsy, but does the job. If your corne...
# 2        So much better than plastic mug types--keeps c...
# 3        I like my coffee hot; borderline scorching but...
# 4        This mug does only a fair job of keeping coffe...
# ...                                                    ...
# 6898950  I purchased these as decorations for my classr...
# 6898951  getting the used tea leaves out of this is ext...
# 6898952  Good deal. It took a while to recieve so I kin...
# 6898953  Great price and okay quality. I know it's not ...
# 6898954  Lightweight and roomy. Perfect for Sunday roasts!
#
#                                               summary   rev_date
# 0                                          Five Stars 2015-11-05
# 1                                                 Meh 2015-05-07
# 2                                           Recommend 2014-01-22
# 3              Not keeping coffee hot for long enough 2013-10-30
# 4            Leaks like a waterfall when at an angle! 2013-09-20
# ...                                               ...        ...
# 6898950                            Beautiful Pom poms 2016-08-08
# 6898951                  cute but not very functional 2017-09-05
# 6898952  Good deal. It took a while to recieve so ... 2017-07-30
# 6898953                                    Four Stars 2018-07-28
# 6898954                     Perfect for Sunday roasts 2018-07-22
#
# [6297973 rows x 6 columns]

# %%
#Sorting the rows by rev_date , old reviews to latest reviews
df = df.sort_values(by = 'rev_date')

# %%
#ADD CODE for finding duplicates
df[df.duplicated(subset = ['asin','reviewerID'], keep = 'last')]
# Out:
#          overall      reviewerID        asin  \
# 21535        5.0    ALJGB7XHPFCR  B00004R92U
# 21690        5.0    ALJGB7XHPFCR  B00004R92U
# 43596        5.0  A231WM2Z2JL0U3  B00004SQ0K
# 27889        5.0   AX54G5AL870Q8  B00004RG94
# 41002        4.0   AJF1X7RTIDD8Y  B00004SDTC
# ...          ...             ...         ...
# 6788951      5.0  A30LCBJWW8EJXZ  B015MSI8WQ
# 5846814      5.0  A2NMV73BMOZCAR  B01CKM4DVC
# 6871015      5.0  A20E61JYFUYE7B  B01EGRZB5Q
# 6847758      3.0  A2SHJ3Y65BE7RT  B01C5JFOYU
# 6892032      4.0  A1YPW8Q50UNQ8L  B01GS4JH1Y
#
#                                                 reviewText  \
# 21535    After mixing your dough and letting it rise th...
# 21690    After mixing your dough and letting it rise th...
# 43596    I've had mine for quite some time, and I would...
# 27889    Why do I like these so much?  Because the othe...
# 41002    This toaster toasts just fine.  The bread come...
# ...                                                    ...
# 6788951  This is a great gift for kids! It's Suitable f...
# 5846814                                    They work great
# 6871015                                               good
# 6847758  I was a bit displeased with these as they're s...
# 6892032              More orange than red but good quality
#
#                                       summary   rev_date
# 21535               BETTER THAN SLICED BREAD! 2000-06-30
# 21690               A great bread-making tool 2000-07-11
# 43596                 Perfect Results Always. 2000-09-05
# 27889    My favorite set of measuring spoons. 2000-10-19
# 41002                It's a fine toaster, but 2001-06-22
# ...                                       ...        ...
# 6788951         This is a great gift for kids 2018-09-01
# 5846814                             Love them 2018-09-04
# 6871015                            Five Stars 2018-09-05
# 6847758                     Wouldnt buy again 2018-09-05
# 6892032                  More orange than red 2018-09-16
#
# [244593 rows x 6 columns]

# %%
#Deleting these duplicate values keeping the latest review (the last value found)
df.drop_duplicates(subset = ['asin','reviewerID'], keep ='last', inplace = True)

# %%
df
# Out:
#          overall      reviewerID        asin  \
# 20870        4.0  A2MNB77YGJ3CN0  B00004R940
# 34742        5.0  A1LUUO72VAFKFJ  B00004S4TZ
# 24851        5.0   ALSQSIHU2ETLM  B00004RDAZ
# 35097        2.0  A2E041EYGSY0HK  B00004S576
# 40953        5.0  A2RQOO8VYAEZZG  B00004SBIB
# ...          ...             ...         ...
# 6897070      5.0  A2JROYIK9FSAL6  B01HCJCM52
# 6898692      5.0  A3A1GEBNMXSWQE  B01HIAZ9BY
# 6898693      5.0  A3JE6DTQ3CZ2Q1  B01HIAZ9BY
# 6898453      5.0  A13KGVUSBEI7XG  B01HHAW9HW
# 6898510      5.0   AK4J1C3HVCG68  B01HHHGFQ6
#
#                                                 reviewText  \
# 20870    I'll admit it -- I'm a bit of a snob when it c...
# 34742    Maybe when Mom cooked for a big family every d...
# 24851    This was an impulse buy, I was looking for a b...
# 35097    I bought this rice cooker based on the first t...
# 40953    I went mad when I first saw this amazing cassa...
# ...                                                    ...
# 6897070  These are exactly what I was looking for to so...
# 6898692         Looks cheap but its sturdy to my surprise.
# 6898693                             Great look and quality
# 6898453  This is a great lunchbox. My daughter loves th...
# 6898510           well made and comfortable, as advertised
#
#                                                    summary   rev_date
# 20870              I was skeptical, but now I'm sold . . . 2000-05-07
# 34742    Superb.  Why didn't somebody think of this yea... 2000-05-19
# 24851                   What a wonderful kitchen appliance 2000-05-31
# 35097                                  Really disappointed 2000-05-31
# 40953                        The lovliest Le Creuset ever! 2000-06-12
# ...                                                    ...        ...
# 6897070                            Perfect sheer curtains! 2018-10-03
# 6898692                                Great. Do recommend 2018-10-03
# 6898693                                      Great product 2018-10-03
# 6898453                               Its a good lunchbox. 2018-10-04
# 6898510                                         Five Stars 2018-10-04
#
# [6053380 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# overall          0
# reviewerID       0
# asin             0
# reviewText    2376
# summary       1205
# rev_date         0
# dtype: int64

# %%
#Check if both summary and review text are nan, delete those rows
cols = ['reviewText','summary']
df[df[cols].isnull().all(axis=1)]
# Out:
#          overall      reviewerID        asin reviewText summary   rev_date
# 3797106      5.0  A3DHCIDXXT0GO8  B00GCAHDJ8        NaN     NaN 2014-08-31
# 1137142      4.0  A2XX64MZUGGR35  B000XU49MW        NaN     NaN 2014-09-04
# 1677887      5.0  A3DHCIDXXT0GO8  B00240AIIS        NaN     NaN 2014-09-08
# 272221       3.0  A3SVGK8VCGYCOP  B0001MSDOC        NaN     NaN 2015-02-04
# 3209944      5.0  A3DHCIDXXT0GO8  B00AYTGPWE        NaN     NaN 2015-04-18
# ...          ...             ...         ...        ...     ...        ...
# 6716009      5.0  A1B6CFBNB9IE9C  B00UN0CMIA        NaN     NaN 2018-08-02
# 6815209      5.0  A2GVLM4T84L897  B018CLK436        NaN     NaN 2018-08-22
# 6767018      5.0  A2GVLM4T84L897  B012TXB572        NaN     NaN 2018-08-22
# 6820573      5.0  A2GVLM4T84L897  B0193K02LO        NaN     NaN 2018-08-22
# 5197960      5.0  A3BUCY4K6FALC3  B010T1QZAI        NaN     NaN 2018-08-25
#
# [84 rows x 6 columns]

# %%
idx = df[df[cols].isnull().all(axis=1)].index

# %%
df.drop(idx,inplace=True)

# %%
#Get all the indexes of reviewtext which has url
df.summary[df.summary.str.match(pat = '(https)|(http)|(www.)',na = False)]
# Out:
# 1352090    http://www.amazon.com/gp/product/B0019S20CS/re...
# 1055867    http://www.amazon.com/gp/product/B0016NQ49Q/re...
# 100084     http://www.amazon.com/gp/product/B0000631ZM/re...
# 86087      http://www.amazon.com/gp/aw/d/B00005NCWS/ref=a...
# 3645618    http://www.amazon.com/gp/product/B00EUWISFS/re...
#                                  ...
# 6892309                                https: //www. amazon.
# 4584161                                https: //www. amazon.
# 6025261                                https: //www. amazon.
# 6086577                                https: //www. amazon.
# 6517350                                https: //www. amazon.
# Name: summary, Length: 235, dtype: object

# %%
#store the index
ids = df.summary[df.summary.str.match(pat = '(https)|(http)|(www.)',na = False)].index

# %%
#display a sample summary with url
df.summary[1352090]
# Out:
# 'http://www.amazon.com/gp/product/B0019S20CS/ref=cm_cr_rev_prod_title'

# %%
#Replace url with ''
for i in ids:
    df.summary[i]=''
# Out:
# /home/014544907/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#double check all summary if it still has url
id_s = df[df.summary.str.match(pat = '(https)|(http)|(www.)',na = False)].index

# %%
#Index of all the summary which has urls
id_s
# Out:
# Int64Index([], dtype='int64')

# %%
#combine both review and summary texts
df['reviewText'] = df[['reviewText', 'summary']].astype(str).apply(lambda x: ' //'.join(x), axis = 1)

# %%
#deleting summary column
del df['summary']

# %%
#reset index
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#          overall      reviewerID        asin  \
# 0            4.0  A2MNB77YGJ3CN0  B00004R940
# 1            5.0  A1LUUO72VAFKFJ  B00004S4TZ
# 2            5.0   ALSQSIHU2ETLM  B00004RDAZ
# 3            2.0  A2E041EYGSY0HK  B00004S576
# 4            5.0  A2RQOO8VYAEZZG  B00004SBIB
# ...          ...             ...         ...
# 6053291      5.0  A2JROYIK9FSAL6  B01HCJCM52
# 6053292      5.0  A3A1GEBNMXSWQE  B01HIAZ9BY
# 6053293      5.0  A3JE6DTQ3CZ2Q1  B01HIAZ9BY
# 6053294      5.0  A13KGVUSBEI7XG  B01HHAW9HW
# 6053295      5.0   AK4J1C3HVCG68  B01HHHGFQ6
#
#                                                 reviewText   rev_date
# 0        I'll admit it -- I'm a bit of a snob when it c... 2000-05-07
# 1        Maybe when Mom cooked for a big family every d... 2000-05-19
# 2        This was an impulse buy, I was looking for a b... 2000-05-31
# 3        I bought this rice cooker based on the first t... 2000-05-31
# 4        I went mad when I first saw this amazing cassa... 2000-06-12
# ...                                                    ...        ...
# 6053291  These are exactly what I was looking for to so... 2018-10-03
# 6053292  Looks cheap but its sturdy to my surprise. //G... 2018-10-03
# 6053293             Great look and quality //Great product 2018-10-03
# 6053294  This is a great lunchbox. My daughter loves th... 2018-10-04
# 6053295  well made and comfortable, as advertised //Fiv... 2018-10-04
#
# [6053296 rows x 5 columns]

# %%
#code for removing url in any form
import re
def remove_urls (vTEXT):
    vTEXT = re.sub(r'(https|http|www)(://|\.)(\w|\.|\/|\?|\=|\&|\%|[-]|\///)*\b', '', vTEXT, flags=re.MULTILINE)
    return(vTEXT)

# %%
#Get all the indexes of reviewtext which has url
idrev = df[df.reviewText.str.match(pat = '(https)|(http)|(www.)')].index

# %%
#Index of all the reviews which has urls
idrev
# Out:
# Int64Index([  29728,   77664,   97556,  153047,  191329,  232195,  318518,
#              361580, 1015598, 1018903,
#             ...
#             5794295, 5852077, 5867727, 5868000, 5897110, 5904426, 5918600,
#             5918893, 5937074, 5996423],
#            dtype='int64', length=265)

# %%
#Check a sample review test with url
df.reviewText[29728]
# Out:
# 'http://www.amazon.com/SCG-5057-Bacon-Wave/dp/B0016P1AFM\n\nThe good news is that the bacon is literally grease-free, retains its shape and cooks to perfection.\n\nThe BAD news is that the composite material warped badly on the first use, despite instructions being followed. It is still usuable but this design and the materials needs to be improved. //Bacon Wave - the Good news and the Bad news'

# %%
#After removing url
remove_urls(df.reviewText[29728])
# Out:
# '\n\nThe good news is that the bacon is literally grease-free, retains its shape and cooks to perfection.\n\nThe BAD news is that the composite material warped badly on the first use, despite instructions being followed. It is still usuable but this design and the materials needs to be improved. //Bacon Wave - the Good news and the Bad news'

# %%
#Remove url for all the indexes which had url
for i in idrev:
    df.reviewText[i] = remove_urls(df.reviewText[i])
# Out:
# /home/014544907/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Double check if reviewtext still contains http/www
idrev = df[df.reviewText.str.match(pat = '(https)|(http)|(www.)')].index

# %%
#check index
idrev
# Out:
# Int64Index([], dtype='int64')

# %%
#Check for null values
df.isnull().sum()
# Out:
# overall       0
# reviewerID    0
# asin          0
# reviewText    0
# rev_date      0
# dtype: int64

# %%
df
# Out:
#          overall      reviewerID        asin  \
# 0            4.0  A2MNB77YGJ3CN0  B00004R940
# 1            5.0  A1LUUO72VAFKFJ  B00004S4TZ
# 2            5.0   ALSQSIHU2ETLM  B00004RDAZ
# 3            2.0  A2E041EYGSY0HK  B00004S576
# 4            5.0  A2RQOO8VYAEZZG  B00004SBIB
# ...          ...             ...         ...
# 6053291      5.0  A2JROYIK9FSAL6  B01HCJCM52
# 6053292      5.0  A3A1GEBNMXSWQE  B01HIAZ9BY
# 6053293      5.0  A3JE6DTQ3CZ2Q1  B01HIAZ9BY
# 6053294      5.0  A13KGVUSBEI7XG  B01HHAW9HW
# 6053295      5.0   AK4J1C3HVCG68  B01HHHGFQ6
#
#                                                 reviewText   rev_date
# 0        I'll admit it -- I'm a bit of a snob when it c... 2000-05-07
# 1        Maybe when Mom cooked for a big family every d... 2000-05-19
# 2        This was an impulse buy, I was looking for a b... 2000-05-31
# 3        I bought this rice cooker based on the first t... 2000-05-31
# 4        I went mad when I first saw this amazing cassa... 2000-06-12
# ...                                                    ...        ...
# 6053291  These are exactly what I was looking for to so... 2018-10-03
# 6053292  Looks cheap but its sturdy to my surprise. //G... 2018-10-03
# 6053293             Great look and quality //Great product 2018-10-03
# 6053294  This is a great lunchbox. My daughter loves th... 2018-10-04
# 6053295  well made and comfortable, as advertised //Fiv... 2018-10-04
#
# [6053296 rows x 5 columns]

# %%
#Check if overall contains valid rating
df.overall.unique()
# Out:
# array([4., 5., 2., 1., 3.])

# %%
df[df.reviewText.str.contains(' NaN ')==True]
# Out:
# Empty DataFrame
# Columns: [overall, reviewerID, asin, reviewText, rev_date]
# Index: []

# %%
df.to_pickle('Clean_data')
